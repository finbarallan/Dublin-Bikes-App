# %%
import requests
import json
import time
from datetime import datetime 
import sqlalchemy as sqla
from sqlalchemy import create_engine

URI = "dublinbikesdb.ctnqnsdsyxei.us-east-1.rds.amazonaws.com"
PASSWORD = "Grouptwentysix"
PORT = "3306"
DB = "dbbikes"
USER = "Group26"

engine = create_engine("mysql+mysqldb://{}:{}@{}:{}/{}".format(USER, PASSWORD, URI, PORT, DB), echo=True)

def availability_to_db(text):
    stations = json.loads(text)
    now = datetime.now()
    print(type(stations), len(stations)) 
    for station in stations:
        print (station)
        vals = (int(station.get('number')), int(station.get('available_bikes')), int(station.get('available_bike_stands')), datetime.timestamp(now))
        engine.execute("insert into availability values (%s,%s,%s,%s)",vals)
    return

url = "https://api.jcdecaux.com/vls/v1/stations?contract=Dublin&apiKey=a572dc37b128fb280c9e1621093640367863e160"
response = requests.get(url)
stations = json.loads(response.text)

while True:
    availability_to_db(response.text)
    time.sleep(5*60)
# Out:
# <class 'list'> 114
# {'number': 42, 'contract_name': 'dublin', 'name': 'SMITHFIELD NORTH', 'address': 'Smithfield North', 'position': {'lat': 53.349562, 'lng': -6.278198}, 'banking': False, 'bonus': False, 'bike_stands': 30, 'available_bike_stands': 19, 'available_bikes': 10, 'status': 'OPEN', 'last_update': 1677231348000}
# 2023-02-24 09:39:26,503 INFO sqlalchemy.engine.Engine SELECT DATABASE()
# 2023-02-24 09:39:26,505 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-02-24 09:39:26,820 INFO sqlalchemy.engine.Engine SELECT @@sql_mode
# 2023-02-24 09:39:26,822 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-02-24 09:39:26,914 INFO sqlalchemy.engine.Engine SELECT @@lower_case_table_names
# 2023-02-24 09:39:26,916 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-02-24 09:39:27,214 INFO sqlalchemy.engine.Engine insert into availability values (%s,%s,%s,%s)
# 2023-02-24 09:39:27,216 INFO sqlalchemy.engine.Engine [raw sql] (42, 10, 19, 1677231565.537707)
# 2023-02-24 09:39:27,345 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 30, 'contract_name': 'dublin', 'name': 'PARNELL SQUARE NORTH', 'address': 'Parnell Square North', 'position': {'lat': 53.3537415547453, 'lng': -6.26530144781526}, 'banking': False, 'bonus': False, 'bike_stands': 20, 'available_bike_stands': 3, 'available_bikes': 17, 'status': 'OPEN', 'last_update': 1677231318000}
# 2023-02-24 09:39:27,547 INFO sqlalchemy.engine.Engine insert into availability values (%s,%s,%s,%s)
# 2023-02-24 09:39:27,550 INFO sqlalchemy.engine.Engine [raw sql] (30, 17, 3, 1677231565.537707)
# 2023-02-24 09:39:27,652 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 54, 'contract_name': 'dublin', 'name': 'CLONMEL STREET', 'address': 'Clonmel Street', 'position': {'lat': 53.336021, 'lng': -6.26298}, 'banking': False, 'bonus': False, 'bike_stands': 33, 'available_bike_stands': 21, 'available_bikes': 12, 'status': 'OPEN', 'last_update': 1677231339000}
# 2023-02-24 09:39:27,962 INFO sqlalchemy.engine.Engine insert into availability values (%s,%s,%s,%s)
# 2023-02-24 09:39:27,963 INFO sqlalchemy.engine.Engine [raw sql] (54, 12, 21, 1677231565.537707)
# 2023-02-24 09:39:28,074 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 108, 'contract_name': 'dublin', 'name': 'AVONDALE ROAD', 'address': 'Avondale Road', 'position': {'lat': 53.359405, 'lng': -6.276142}, 'banking': False, 'bonus': False, 'bike_stands': 35, 'available_bike_stands': 28, 'available_bikes': 7, 'status': 'OPEN', 'last_update': 1677231154000}
# 2023-02-24 09:39:28,390 INFO sqlalchemy.engine.Engine insert into availability values (%s,%s,%s,%s)
# 2023-02-24 09:39:28,391 INFO sqlalchemy.engine.Engine [raw sql] (108, 7, 28, 1677231565.537707)
# 2023-02-24 09:39:28,507 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 20, 'contract_name': 'dublin', 'name': 'JAMES STREET EAST', 'address': 'James Street East', 'position': {'lat': 53.336597, 'lng': -6.248109}, 'banking': False, 'bonus': False, 'bike_stands': 30, 'available_bike_stands': 14, 'available_bikes': 16, 'status': 'OPEN', 'last_update': 1677231353000}
# 2023-02-24 09:39:28,696 INFO sqlalchemy.engine.Engine insert into availability values (%s,%s,%s,%s)
# 2023-02-24 09:39:28,697 INFO sqlalchemy.engine.Engine [raw sql] (20, 16, 14, 1677231565.537707)
# 2023-02-24 09:39:28,916 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 56, 'contract_name': 'dublin', 'name': 'MOUNT STREET LOWER', 'address': 'Mount Street Lower', 'position': {'lat': 53.33796, 'lng': -6.24153}, 'banking': False, 'bonus': False, 'bike_stands': 40, 'available_bike_stands': 19, 'available_bikes': 21, 'status': 'OPEN', 'last_update': 1677231492000}
# 2023-02-24 09:39:29,105 INFO sqlalchemy.engine.Engine insert into availability values (%s,%s,%s,%s)
# 2023-02-24 09:39:29,108 INFO sqlalchemy.engine.Engine [raw sql] (56, 21, 19, 1677231565.537707)
# 2023-02-24 09:39:29,206 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 6, 'contract_name': 'dublin', 'name': 'CHRISTCHURCH PLACE', 'address': 'Christchurch Place', 'position': {'lat': 53.343368, 'lng': -6.27012}, 'banking': False, 'bonus': False, 'bike_stands': 20, 'available_bike_stands': 19, 'available_bikes': 1, 'status': 'OPEN', 'last_update': 1677231089000}
# 2023-02-24 09:39:29,442 INFO sqlalchemy.engine.Engine insert into availability values (%s,%s,%s,%s)
# 2023-02-24 09:39:29,444 INFO sqlalchemy.engine.Engine [raw sql] (6, 1, 19, 1677231565.537707)
# 2023-02-24 09:39:29,544 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 18, 'contract_name': 'dublin', 'name': 'GRANTHAM STREET', 'address': 'Grantham Street', 'position': {'lat': 53.334123, 'lng': -6.265436}, 'banking': False, 'bonus': False, 'bike_stands': 30, 'available_bike_stands': 19, 'available_bikes': 11, 'status': 'OPEN', 'last_update': 1677231466000}
# 2023-02-24 09:39:29,744 INFO sqlalchemy.engine.Engine insert into availability values (%s,%s,%s,%s)
# 2023-02-24 09:39:29,747 INFO sqlalchemy.engine.Engine [raw sql] (18, 11, 19, 1677231565.537707)
# 2023-02-24 09:39:29,964 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 32, 'contract_name': 'dublin', 'name': 'PEARSE STREET', 'address': 'Pearse Street', 'position': {'lat': 53.344304, 'lng': -6.250427}, 'banking': False, 'bonus': False, 'bike_stands': 30, 'available_bike_stands': 5, 'available_bikes': 25, 'status': 'OPEN', 'last_update': 1677231388000}
# 2023-02-24 09:39:30,157 INFO sqlalchemy.engine.Engine insert into availability values (%s,%s,%s,%s)
# 2023-02-24 09:39:30,158 INFO sqlalchemy.engine.Engine [raw sql] (32, 25, 5, 1677231565.537707)
# 2023-02-24 09:39:30,261 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 52, 'contract_name': 'dublin', 'name': 'YORK STREET EAST', 'address': 'York Street East', 'position': {'lat': 53.338755, 'lng': -6.262003}, 'banking': False, 'bonus': False, 'bike_stands': 32, 'available_bike_stands': 21, 'available_bikes': 11, 'status': 'OPEN', 'last_update': 1677230990000}
# 2023-02-24 09:39:30,579 INFO sqlalchemy.engine.Engine insert into availability values (%s,%s,%s,%s)
# 2023-02-24 09:39:30,582 INFO sqlalchemy.engine.Engine [raw sql] (52, 11, 21, 1677231565.537707)
# 2023-02-24 09:39:30,680 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 48, 'contract_name': 'dublin', 'name': 'EXCISE WALK', 'address': 'Excise Walk', 'position': {'lat': 53.347777, 'lng': -6.244239}, 'banking': False, 'bonus': False, 'bike_stands': 40, 'available_bike_stands': 22, 'available_bikes': 18, 'status': 'OPEN', 'last_update': 1677231012000}
# 2023-02-24 09:39:31,015 INFO sqlalchemy.engine.Engine insert into availability values (%s,%s,%s,%s)
# 2023-02-24 09:39:31,017 INFO sqlalchemy.engine.Engine [raw sql] (48, 18, 22, 1677231565.537707)
# 2023-02-24 09:39:31,110 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 13, 'contract_name': 'dublin', 'name': 'FITZWILLIAM SQUARE WEST', 'address': 'Fitzwilliam Square West', 'position': {'lat': 53.336074, 'lng': -6.252825}, 'banking': False, 'bonus': False, 'bike_stands': 30, 'available_bike_stands': 12, 'available_bikes': 18, 'status': 'OPEN', 'last_update': 1677230973000}
# 2023-02-24 09:39:31,308 INFO sqlalchemy.engine.Engine insert into availability values (%s,%s,%s,%s)
# 2023-02-24 09:39:31,310 INFO sqlalchemy.engine.Engine [raw sql] (13, 18, 12, 1677231565.537707)
# 2023-02-24 09:39:31,412 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 43, 'contract_name': 'dublin', 'name': 'PORTOBELLO ROAD', 'address': 'Portobello Road', 'position': {'lat': 53.330091, 'lng': -6.268044}, 'banking': False, 'bonus': False, 'bike_stands': 30, 'available_bike_stands': 30, 'available_bikes': 0, 'status': 'OPEN', 'last_update': 1677231428000}
# 2023-02-24 09:39:31,630 INFO sqlalchemy.engine.Engine insert into availability values (%s,%s,%s,%s)
# 2023-02-24 09:39:31,633 INFO sqlalchemy.engine.Engine [raw sql] (43, 0, 30, 1677231565.537707)
# 2023-02-24 09:39:31,725 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 31, 'contract_name': 'dublin', 'name': 'PARNELL STREET', 'address': 'Parnell Street', 'position': {'lat': 53.350929, 'lng': -6.265125}, 'banking': False, 'bonus': False, 'bike_stands': 20, 'available_bike_stands': 9, 'available_bikes': 11, 'status': 'OPEN', 'last_update': 1677231006000}
# 2023-02-24 09:39:32,063 INFO sqlalchemy.engine.Engine insert into availability values (%s,%s,%s,%s)
# 2023-02-24 09:39:32,065 INFO sqlalchemy.engine.Engine [raw sql] (31, 11, 9, 1677231565.537707)
# 2023-02-24 09:39:32,159 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 98, 'contract_name': 'dublin', 'name': 'FREDERICK STREET SOUTH', 'address': 'Frederick Street South', 'position': {'lat': 53.341515, 'lng': -6.256853}, 'banking': False, 'bonus': False, 'bike_stands': 40, 'available_bike_stands': 31, 'available_bikes': 9, 'status': 'OPEN', 'last_update': 1677231200000}
# 2023-02-24 09:39:32,354 INFO sqlalchemy.engine.Engine insert into availability values (%s,%s,%s,%s)
# 2023-02-24 09:39:32,356 INFO sqlalchemy.engine.Engine [raw sql] (98, 9, 31, 1677231565.537707)
# 2023-02-24 09:39:32,456 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 14, 'contract_name': 'dublin', 'name': 'FOWNES STREET UPPER', 'address': 'Fownes Street Upper', 'position': {'lat': 53.344603, 'lng': -6.263371}, 'banking': False, 'bonus': False, 'bike_stands': 30, 'available_bike_stands': 9, 'available_bikes': 21, 'status': 'OPEN', 'last_update': 1677231365000}
# 2023-02-24 09:39:32,676 INFO sqlalchemy.engine.Engine insert into availability values (%s,%s,%s,%s)
# 2023-02-24 09:39:32,679 INFO sqlalchemy.engine.Engine [raw sql] (14, 21, 9, 1677231565.537707)
# 2023-02-24 09:39:32,772 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 1, 'contract_name': 'dublin', 'name': 'CLARENDON ROW', 'address': 'Clarendon Row', 'position': {'lat': 53.340927, 'lng': -6.262501}, 'banking': False, 'bonus': False, 'bike_stands': 31, 'available_bike_stands': 11, 'available_bikes': 20, 'status': 'OPEN', 'last_update': 1677231239000}
# 2023-02-24 09:39:33,112 INFO sqlalchemy.engine.Engine insert into availability values (%s,%s,%s,%s)
# 2023-02-24 09:39:33,114 INFO sqlalchemy.engine.Engine [raw sql] (1, 20, 11, 1677231565.537707)
# 2023-02-24 09:39:33,206 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 23, 'contract_name': 'dublin', 'name': 'CUSTOM HOUSE', 'address': 'Custom House', 'position': {'lat': 53.348279, 'lng': -6.254662}, 'banking': False, 'bonus': False, 'bike_stands': 30, 'available_bike_stands': 1, 'available_bikes': 29, 'status': 'OPEN', 'last_update': 1677231268000}
# 2023-02-24 09:39:33,407 INFO sqlalchemy.engine.Engine insert into availability values (%s,%s,%s,%s)
# 2023-02-24 09:39:33,409 INFO sqlalchemy.engine.Engine [raw sql] (23, 29, 1, 1677231565.537707)
# 2023-02-24 09:39:33,504 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 106, 'contract_name': 'dublin', 'name': 'RATHDOWN ROAD', 'address': 'Rathdown Road', 'position': {'lat': 53.35893, 'lng': -6.280337}, 'banking': False, 'bonus': False, 'bike_stands': 40, 'available_bike_stands': 32, 'available_bikes': 8, 'status': 'OPEN', 'last_update': 1677231212000}
# 2023-02-24 09:39:33,726 INFO sqlalchemy.engine.Engine insert into availability values (%s,%s,%s,%s)
# 2023-02-24 09:39:33,728 INFO sqlalchemy.engine.Engine [raw sql] (106, 8, 32, 1677231565.537707)
# 2023-02-24 09:39:33,822 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 112, 'contract_name': 'dublin', 'name': "NORTH CIRCULAR ROAD (O'CONNELL'S)", 'address': "North Circular Road (O'Connell's)", 'position': {'lat': 53.357841, 'lng': -6.251557}, 'banking': False, 'bonus': False, 'bike_stands': 30, 'available_bike_stands': 27, 'available_bikes': 2, 'status': 'OPEN', 'last_update': 1677231383000}
# 2023-02-24 09:39:34,355 INFO sqlalchemy.engine.Engine insert into availability values (%s,%s,%s,%s)
# 2023-02-24 09:39:34,358 INFO sqlalchemy.engine.Engine [raw sql] (112, 2, 27, 1677231565.537707)
# 2023-02-24 09:39:34,450 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 68, 'contract_name': 'dublin', 'name': 'HANOVER QUAY', 'address': 'Hanover Quay', 'position': {'lat': 53.344115, 'lng': -6.237153}, 'banking': False, 'bonus': False, 'bike_stands': 40, 'available_bike_stands': 34, 'available_bikes': 6, 'status': 'OPEN', 'last_update': 1677231031000}
# 2023-02-24 09:39:34,973 INFO sqlalchemy.engine.Engine insert into availability values (%s,%s,%s,%s)
# 2023-02-24 09:39:34,975 INFO sqlalchemy.engine.Engine [raw sql] (68, 6, 34, 1677231565.537707)
# 2023-02-24 09:39:35,211 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 74, 'contract_name': 'dublin', 'name': 'OLIVER BOND STREET', 'address': 'Oliver Bond Street', 'position': {'lat': 53.343893, 'lng': -6.280531}, 'banking': False, 'bonus': False, 'bike_stands': 30, 'available_bike_stands': 27, 'available_bikes': 3, 'status': 'OPEN', 'last_update': 1677231400000}
# 2023-02-24 09:39:35,407 INFO sqlalchemy.engine.Engine insert into availability values (%s,%s,%s,%s)
# 2023-02-24 09:39:35,409 INFO sqlalchemy.engine.Engine [raw sql] (74, 3, 27, 1677231565.537707)
# 2023-02-24 09:39:35,504 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 87, 'contract_name': 'dublin', 'name': 'COLLINS BARRACKS MUSEUM', 'address': 'Collins Barracks Museum', 'position': {'lat': 53.347477, 'lng': -6.28525}, 'banking': False, 'bonus': False, 'bike_stands': 38, 'available_bike_stands': 23, 'available_bikes': 15, 'status': 'OPEN', 'last_update': 1677231252000}
# 2023-02-24 09:39:35,731 INFO sqlalchemy.engine.Engine insert into availability values (%s,%s,%s,%s)
# 2023-02-24 09:39:35,733 INFO sqlalchemy.engine.Engine [raw sql] (87, 15, 23, 1677231565.537707)
# 2023-02-24 09:39:35,826 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 84, 'contract_name': 'dublin', 'name': 'BROOKFIELD ROAD', 'address': 'Brookfield Road', 'position': {'lat': 53.339005, 'lng': -6.300217}, 'banking': False, 'bonus': False, 'bike_stands': 30, 'available_bike_stands': 18, 'available_bikes': 11, 'status': 'OPEN', 'last_update': 1677231314000}
# 2023-02-24 09:39:36,027 INFO sqlalchemy.engine.Engine insert into availability values (%s,%s,%s,%s)
# 2023-02-24 09:39:36,030 INFO sqlalchemy.engine.Engine [raw sql] (84, 11, 18, 1677231565.537707)
# 2023-02-24 09:39:36,256 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 90, 'contract_name': 'dublin', 'name': 'BENSON STREET', 'address': 'Benson Street', 'position': {'lat': 53.344153, 'lng': -6.233451}, 'banking': False, 'bonus': False, 'bike_stands': 40, 'available_bike_stands': 17, 'available_bikes': 23, 'status': 'OPEN', 'last_update': 1677231393000}
# 2023-02-24 09:39:36,445 INFO sqlalchemy.engine.Engine insert into availability values (%s,%s,%s,%s)
# 2023-02-24 09:39:36,447 INFO sqlalchemy.engine.Engine [raw sql] (90, 23, 17, 1677231565.537707)
# 2023-02-24 09:39:36,540 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 11, 'contract_name': 'dublin', 'name': 'EARLSFORT TERRACE', 'address': 'Earlsfort Terrace', 'position': {'lat': 53.334295, 'lng': -6.258503}, 'banking': False, 'bonus': False, 'bike_stands': 30, 'available_bike_stands': 21, 'available_bikes': 9, 'status': 'OPEN', 'last_update': 1677231042000}
# 2023-02-24 09:39:36,781 INFO sqlalchemy.engine.Engine insert into availability values (%s,%s,%s,%s)
# 2023-02-24 09:39:36,783 INFO sqlalchemy.engine.Engine [raw sql] (11, 9, 21, 1677231565.537707)
# 2023-02-24 09:39:36,901 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 17, 'contract_name': 'dublin', 'name': 'GOLDEN LANE', 'address': 'Golden Lane', 'position': {'lat': 53.340803, 'lng': -6.267732}, 'banking': False, 'bonus': False, 'bike_stands': 20, 'available_bike_stands': 20, 'available_bikes': 0, 'status': 'OPEN', 'last_update': 1677231260000}
# 2023-02-24 09:39:37,092 INFO sqlalchemy.engine.Engine insert into availability values (%s,%s,%s,%s)
# 2023-02-24 09:39:37,094 INFO sqlalchemy.engine.Engine [raw sql] (17, 0, 20, 1677231565.537707)
# 2023-02-24 09:39:37,303 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 45, 'contract_name': 'dublin', 'name': 'DEVERELL PLACE', 'address': 'Deverell Place', 'position': {'lat': 53.351464, 'lng': -6.255265}, 'banking': False, 'bonus': False, 'bike_stands': 30, 'available_bike_stands': 17, 'available_bikes': 12, 'status': 'OPEN', 'last_update': 1677231270000}
# 2023-02-24 09:39:37,494 INFO sqlalchemy.engine.Engine insert into availability values (%s,%s,%s,%s)
# 2023-02-24 09:39:37,496 INFO sqlalchemy.engine.Engine [raw sql] (45, 12, 17, 1677231565.537707)
# 2023-02-24 09:39:37,697 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 114, 'contract_name': 'dublin', 'name': 'WILTON TERRACE (PARK)', 'address': 'Wilton Terrace (Park)', 'position': {'lat': 53.333653, 'lng': -6.248345}, 'banking': False, 'bonus': False, 'bike_stands': 40, 'available_bike_stands': 0, 'available_bikes': 40, 'status': 'OPEN', 'last_update': 1677231496000}
# 2023-02-24 09:39:37,927 INFO sqlalchemy.engine.Engine insert into availability values (%s,%s,%s,%s)
# 2023-02-24 09:39:37,930 INFO sqlalchemy.engine.Engine [raw sql] (114, 40, 0, 1677231565.537707)
# 2023-02-24 09:39:38,022 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 72, 'contract_name': 'dublin', 'name': 'JOHN STREET WEST', 'address': 'John Street West', 'position': {'lat': 53.343105, 'lng': -6.277167}, 'banking': False, 'bonus': False, 'bike_stands': 31, 'available_bike_stands': 24, 'available_bikes': 7, 'status': 'OPEN', 'last_update': 1677231376000}
# 2023-02-24 09:39:38,353 INFO sqlalchemy.engine.Engine insert into availability values (%s,%s,%s,%s)
# 2023-02-24 09:39:38,356 INFO sqlalchemy.engine.Engine [raw sql] (72, 7, 24, 1677231565.537707)
# 2023-02-24 09:39:38,448 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 63, 'contract_name': 'dublin', 'name': 'FENIAN STREET', 'address': 'Fenian Street', 'position': {'lat': 53.341428, 'lng': -6.24672}, 'banking': False, 'bonus': False, 'bike_stands': 35, 'available_bike_stands': 16, 'available_bikes': 19, 'status': 'OPEN', 'last_update': 1677231276000}
# 2023-02-24 09:39:38,639 INFO sqlalchemy.engine.Engine insert into availability values (%s,%s,%s,%s)
# 2023-02-24 09:39:38,641 INFO sqlalchemy.engine.Engine [raw sql] (63, 19, 16, 1677231565.537707)
# 2023-02-24 09:39:38,745 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 113, 'contract_name': 'dublin', 'name': 'MERRION SQUARE SOUTH', 'address': 'Merrion Square South', 'position': {'lat': 53.338614, 'lng': -6.248606}, 'banking': False, 'bonus': False, 'bike_stands': 40, 'available_bike_stands': 34, 'available_bikes': 6, 'status': 'OPEN', 'last_update': 1677231188000}
# 2023-02-24 09:39:38,975 INFO sqlalchemy.engine.Engine insert into availability values (%s,%s,%s,%s)
# 2023-02-24 09:39:38,977 INFO sqlalchemy.engine.Engine [raw sql] (113, 6, 34, 1677231565.537707)
# 2023-02-24 09:39:39,078 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 91, 'contract_name': 'dublin', 'name': 'SOUTH DOCK ROAD', 'address': 'South Dock Road', 'position': {'lat': 53.341833, 'lng': -6.231291}, 'banking': False, 'bonus': False, 'bike_stands': 30, 'available_bike_stands': 18, 'available_bikes': 11, 'status': 'OPEN', 'last_update': 1677231360000}
# 2023-02-24 09:39:39,402 INFO sqlalchemy.engine.Engine insert into availability values (%s,%s,%s,%s)
# 2023-02-24 09:39:39,404 INFO sqlalchemy.engine.Engine [raw sql] (91, 11, 18, 1677231565.537707)
# 2023-02-24 09:39:39,518 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 99, 'contract_name': 'dublin', 'name': 'CITY QUAY', 'address': 'City Quay', 'position': {'lat': 53.346637, 'lng': -6.246154}, 'banking': False, 'bonus': False, 'bike_stands': 30, 'available_bike_stands': 23, 'available_bikes': 7, 'status': 'OPEN', 'last_update': 1677231260000}
# 2023-02-24 09:39:39,794 INFO sqlalchemy.engine.Engine insert into availability values (%s,%s,%s,%s)
# 2023-02-24 09:39:39,796 INFO sqlalchemy.engine.Engine [raw sql] (99, 7, 23, 1677231565.537707)
# 2023-02-24 09:39:39,925 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 9, 'contract_name': 'dublin', 'name': 'EXCHEQUER STREET', 'address': 'Exchequer Street', 'position': {'lat': 53.343034, 'lng': -6.263578}, 'banking': False, 'bonus': False, 'bike_stands': 24, 'available_bike_stands': 1, 'available_bikes': 23, 'status': 'OPEN', 'last_update': 1677231155000}
# 2023-02-24 09:39:40,158 INFO sqlalchemy.engine.Engine insert into availability values (%s,%s,%s,%s)
# 2023-02-24 09:39:40,160 INFO sqlalchemy.engine.Engine [raw sql] (9, 23, 1, 1677231565.537707)
# 2023-02-24 09:39:40,252 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 67, 'contract_name': 'dublin', 'name': 'THE POINT', 'address': 'The Point', 'position': {'lat': 53.346867, 'lng': -6.230852}, 'banking': False, 'bonus': False, 'bike_stands': 40, 'available_bike_stands': 25, 'available_bikes': 14, 'status': 'OPEN', 'last_update': 1677231350000}
# 2023-02-24 09:39:40,541 INFO sqlalchemy.engine.Engine insert into availability values (%s,%s,%s,%s)
# 2023-02-24 09:39:40,544 INFO sqlalchemy.engine.Engine [raw sql] (67, 14, 25, 1677231565.537707)
# 2023-02-24 09:39:40,636 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 116, 'contract_name': 'dublin', 'name': 'BROADSTONE', 'address': 'Broadstone', 'position': {'lat': 53.3547, 'lng': -6.272314}, 'banking': False, 'bonus': False, 'bike_stands': 30, 'available_bike_stands': 30, 'available_bikes': 0, 'status': 'OPEN', 'last_update': 1677231176000}
# 2023-02-24 09:39:40,843 INFO sqlalchemy.engine.Engine insert into availability values (%s,%s,%s,%s)
# 2023-02-24 09:39:40,845 INFO sqlalchemy.engine.Engine [raw sql] (116, 0, 30, 1677231565.537707)
# 2023-02-24 09:39:40,977 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 55, 'contract_name': 'dublin', 'name': 'HATCH STREET', 'address': 'Hatch Street', 'position': {'lat': 53.33403, 'lng': -6.260714}, 'banking': False, 'bonus': False, 'bike_stands': 36, 'available_bike_stands': 24, 'available_bikes': 12, 'status': 'OPEN', 'last_update': 1677231145000}
# 2023-02-24 09:39:41,234 INFO sqlalchemy.engine.Engine insert into availability values (%s,%s,%s,%s)
# 2023-02-24 09:39:41,236 INFO sqlalchemy.engine.Engine [raw sql] (55, 12, 24, 1677231565.537707)
# 2023-02-24 09:39:41,500 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 62, 'contract_name': 'dublin', 'name': 'LIME STREET', 'address': 'Lime Street', 'position': {'lat': 53.346026, 'lng': -6.243576}, 'banking': False, 'bonus': False, 'bike_stands': 40, 'available_bike_stands': 17, 'available_bikes': 22, 'status': 'OPEN', 'last_update': 1677231481000}
# 2023-02-24 09:39:41,690 INFO sqlalchemy.engine.Engine insert into availability values (%s,%s,%s,%s)
# 2023-02-24 09:39:41,692 INFO sqlalchemy.engine.Engine [raw sql] (62, 22, 17, 1677231565.537707)
# 2023-02-24 09:39:41,893 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 5, 'contract_name': 'dublin', 'name': 'CHARLEMONT PLACE', 'address': 'Charlemont Street', 'position': {'lat': 53.330662, 'lng': -6.260177}, 'banking': False, 'bonus': False, 'bike_stands': 40, 'available_bike_stands': 34, 'available_bikes': 5, 'status': 'OPEN', 'last_update': 1677231495000}
# 2023-02-24 09:39:42,116 INFO sqlalchemy.engine.Engine insert into availability values (%s,%s,%s,%s)
# 2023-02-24 09:39:42,118 INFO sqlalchemy.engine.Engine [raw sql] (5, 5, 34, 1677231565.537707)
# 2023-02-24 09:39:42,210 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 97, 'contract_name': 'dublin', 'name': 'KILMAINHAM GAOL', 'address': 'Kilmainham Gaol', 'position': {'lat': 53.342113, 'lng': -6.310015}, 'banking': False, 'bonus': False, 'bike_stands': 40, 'available_bike_stands': 28, 'available_bikes': 12, 'status': 'OPEN', 'last_update': 1677231104000}
# 2023-02-24 09:39:42,547 INFO sqlalchemy.engine.Engine insert into availability values (%s,%s,%s,%s)
# 2023-02-24 09:39:42,550 INFO sqlalchemy.engine.Engine [raw sql] (97, 12, 28, 1677231565.537707)
# 2023-02-24 09:39:42,647 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 61, 'contract_name': 'dublin', 'name': 'HARDWICKE PLACE', 'address': 'Hardwicke Place', 'position': {'lat': 53.357043, 'lng': -6.263232}, 'banking': False, 'bonus': False, 'bike_stands': 25, 'available_bike_stands': 12, 'available_bikes': 13, 'status': 'OPEN', 'last_update': 1677231241000}
# 2023-02-24 09:39:42,848 INFO sqlalchemy.engine.Engine insert into availability values (%s,%s,%s,%s)
# 2023-02-24 09:39:42,850 INFO sqlalchemy.engine.Engine [raw sql] (61, 13, 12, 1677231565.537707)
# 2023-02-24 09:39:43,072 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 77, 'contract_name': 'dublin', 'name': 'WOLFE TONE STREET', 'address': 'Wolfe Tone Street', 'position': {'lat': 53.348875, 'lng': -6.267459}, 'banking': False, 'bonus': False, 'bike_stands': 29, 'available_bike_stands': 27, 'available_bikes': 2, 'status': 'OPEN', 'last_update': 1677231483000}
# 2023-02-24 09:39:43,359 INFO sqlalchemy.engine.Engine insert into availability values (%s,%s,%s,%s)
# 2023-02-24 09:39:43,362 INFO sqlalchemy.engine.Engine [raw sql] (77, 2, 27, 1677231565.537707)
# 2023-02-24 09:39:43,793 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 4, 'contract_name': 'dublin', 'name': 'GREEK STREET', 'address': 'Greek Street', 'position': {'lat': 53.346874, 'lng': -6.272976}, 'banking': False, 'bonus': False, 'bike_stands': 20, 'available_bike_stands': 8, 'available_bikes': 12, 'status': 'OPEN', 'last_update': 1677231442000}
# 2023-02-24 09:39:44,120 INFO sqlalchemy.engine.Engine insert into availability values (%s,%s,%s,%s)
# 2023-02-24 09:39:44,121 INFO sqlalchemy.engine.Engine [raw sql] (4, 12, 8, 1677231565.537707)
# 2023-02-24 09:39:44,212 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 49, 'contract_name': 'dublin', 'name': 'GUILD STREET', 'address': 'Guild Street', 'position': {'lat': 53.347932, 'lng': -6.240928}, 'banking': False, 'bonus': False, 'bike_stands': 40, 'available_bike_stands': 9, 'available_bikes': 30, 'status': 'OPEN', 'last_update': 1677231443000}
# 2023-02-24 09:39:44,400 INFO sqlalchemy.engine.Engine insert into availability values (%s,%s,%s,%s)
# 2023-02-24 09:39:44,403 INFO sqlalchemy.engine.Engine [raw sql] (49, 30, 9, 1677231565.537707)
# 2023-02-24 09:39:44,646 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 19, 'contract_name': 'dublin', 'name': 'HERBERT PLACE', 'address': 'Herbert Place', 'position': {'lat': 53.334432, 'lng': -6.245575}, 'banking': False, 'bonus': False, 'bike_stands': 30, 'available_bike_stands': 8, 'available_bikes': 22, 'status': 'OPEN', 'last_update': 1677231452000}
# 2023-02-24 09:39:44,833 INFO sqlalchemy.engine.Engine insert into availability values (%s,%s,%s,%s)
# 2023-02-24 09:39:44,835 INFO sqlalchemy.engine.Engine [raw sql] (19, 22, 8, 1677231565.537707)
# 2023-02-24 09:39:44,926 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 7, 'contract_name': 'dublin', 'name': 'HIGH STREET', 'address': 'High Street', 'position': {'lat': 53.343565, 'lng': -6.275071}, 'banking': False, 'bonus': False, 'bike_stands': 29, 'available_bike_stands': 20, 'available_bikes': 9, 'status': 'OPEN', 'last_update': 1677231177000}
# 2023-02-24 09:39:45,201 INFO sqlalchemy.engine.Engine insert into availability values (%s,%s,%s,%s)
# 2023-02-24 09:39:45,202 INFO sqlalchemy.engine.Engine [raw sql] (7, 9, 20, 1677231565.537707)
# 2023-02-24 09:39:45,315 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 60, 'contract_name': 'dublin', 'name': 'NORTH CIRCULAR ROAD', 'address': 'North Circular Road', 'position': {'lat': 53.359624, 'lng': -6.260348}, 'banking': False, 'bonus': False, 'bike_stands': 30, 'available_bike_stands': 19, 'available_bikes': 11, 'status': 'OPEN', 'last_update': 1677231422000}
# 2023-02-24 09:39:45,514 INFO sqlalchemy.engine.Engine insert into availability values (%s,%s,%s,%s)
# 2023-02-24 09:39:45,515 INFO sqlalchemy.engine.Engine [raw sql] (60, 11, 19, 1677231565.537707)
# 2023-02-24 09:39:45,781 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 102, 'contract_name': 'dublin', 'name': 'WESTERN WAY', 'address': 'Western Way', 'position': {'lat': 53.354929, 'lng': -6.269425}, 'banking': False, 'bonus': False, 'bike_stands': 40, 'available_bike_stands': 29, 'available_bikes': 11, 'status': 'OPEN', 'last_update': 1677231380000}
# 2023-02-24 09:39:46,085 INFO sqlalchemy.engine.Engine insert into availability values (%s,%s,%s,%s)
# 2023-02-24 09:39:46,088 INFO sqlalchemy.engine.Engine [raw sql] (102, 11, 29, 1677231565.537707)
# 2023-02-24 09:39:46,217 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 38, 'contract_name': 'dublin', 'name': 'TALBOT STREET', 'address': 'Talbot Street', 'position': {'lat': 53.350974, 'lng': -6.25294}, 'banking': False, 'bonus': False, 'bike_stands': 40, 'available_bike_stands': 25, 'available_bikes': 14, 'status': 'OPEN', 'last_update': 1677231277000}
# 2023-02-24 09:39:46,449 INFO sqlalchemy.engine.Engine insert into availability values (%s,%s,%s,%s)
# 2023-02-24 09:39:46,452 INFO sqlalchemy.engine.Engine [raw sql] (38, 14, 25, 1677231565.537707)
# 2023-02-24 09:39:46,555 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 53, 'contract_name': 'dublin', 'name': 'NEWMAN HOUSE', 'address': 'Newman House', 'position': {'lat': 53.337132, 'lng': -6.26059}, 'banking': False, 'bonus': False, 'bike_stands': 40, 'available_bike_stands': 29, 'available_bikes': 11, 'status': 'OPEN', 'last_update': 1677231421000}
# 2023-02-24 09:39:46,834 INFO sqlalchemy.engine.Engine insert into availability values (%s,%s,%s,%s)
# 2023-02-24 09:39:46,837 INFO sqlalchemy.engine.Engine [raw sql] (53, 11, 29, 1677231565.537707)
# 2023-02-24 09:39:46,929 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 58, 'contract_name': 'dublin', 'name': "SIR PATRICK DUN'S", 'address': "Sir Patrick's Dun", 'position': {'lat': 53.339218, 'lng': -6.240642}, 'banking': False, 'bonus': False, 'bike_stands': 40, 'available_bike_stands': 12, 'available_bikes': 28, 'status': 'OPEN', 'last_update': 1677231466000}
# 2023-02-24 09:39:47,265 INFO sqlalchemy.engine.Engine insert into availability values (%s,%s,%s,%s)
# 2023-02-24 09:39:47,268 INFO sqlalchemy.engine.Engine [raw sql] (58, 28, 12, 1677231565.537707)
# 2023-02-24 09:39:47,365 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 66, 'contract_name': 'dublin', 'name': 'NEW CENTRAL BANK', 'address': 'New Central Bank', 'position': {'lat': 53.347122, 'lng': -6.234749}, 'banking': False, 'bonus': False, 'bike_stands': 40, 'available_bike_stands': 18, 'available_bikes': 22, 'status': 'OPEN', 'last_update': 1677231398000}
# 2023-02-24 09:39:47,602 INFO sqlalchemy.engine.Engine insert into availability values (%s,%s,%s,%s)
# 2023-02-24 09:39:47,604 INFO sqlalchemy.engine.Engine [raw sql] (66, 22, 18, 1677231565.537707)
# 2023-02-24 09:39:47,789 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 104, 'contract_name': 'dublin', 'name': 'GRANGEGORMAN LOWER (CENTRAL)', 'address': 'Grangegorman Lower (Central)', 'position': {'lat': 53.355173, 'lng': -6.278424}, 'banking': False, 'bonus': False, 'bike_stands': 40, 'available_bike_stands': 40, 'available_bikes': 0, 'status': 'OPEN', 'last_update': 1677230913000}
# 2023-02-24 09:39:48,039 INFO sqlalchemy.engine.Engine insert into availability values (%s,%s,%s,%s)
# 2023-02-24 09:39:48,041 INFO sqlalchemy.engine.Engine [raw sql] (104, 0, 40, 1677231565.537707)
# 2023-02-24 09:39:48,185 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 101, 'contract_name': 'dublin', 'name': 'KING STREET NORTH', 'address': 'King Street North', 'position': {'lat': 53.350291, 'lng': -6.273507}, 'banking': False, 'bonus': False, 'bike_stands': 30, 'available_bike_stands': 19, 'available_bikes': 10, 'status': 'OPEN', 'last_update': 1677231369000}
# 2023-02-24 09:39:48,404 INFO sqlalchemy.engine.Engine insert into availability values (%s,%s,%s,%s)
# 2023-02-24 09:39:48,405 INFO sqlalchemy.engine.Engine [raw sql] (101, 10, 19, 1677231565.537707)
# 2023-02-24 09:39:48,497 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 115, 'contract_name': 'dublin', 'name': 'KILLARNEY STREET', 'address': 'Killarney Street', 'position': {'lat': 53.354845, 'lng': -6.247579}, 'banking': False, 'bonus': False, 'bike_stands': 30, 'available_bike_stands': 17, 'available_bikes': 11, 'status': 'OPEN', 'last_update': 1677230923000}
# 2023-02-24 09:39:48,837 INFO sqlalchemy.engine.Engine insert into availability values (%s,%s,%s,%s)
# 2023-02-24 09:39:48,838 INFO sqlalchemy.engine.Engine [raw sql] (115, 11, 17, 1677231565.537707)
# 2023-02-24 09:39:48,943 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 47, 'contract_name': 'dublin', 'name': 'HERBERT STREET', 'address': 'Herbert Street', 'position': {'lat': 53.335742, 'lng': -6.24551}, 'banking': False, 'bonus': False, 'bike_stands': 40, 'available_bike_stands': 34, 'available_bikes': 6, 'status': 'OPEN', 'last_update': 1677231112000}
# 2023-02-24 09:39:49,233 INFO sqlalchemy.engine.Engine insert into availability values (%s,%s,%s,%s)
# 2023-02-24 09:39:49,234 INFO sqlalchemy.engine.Engine [raw sql] (47, 6, 34, 1677231565.537707)
# 2023-02-24 09:39:49,361 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 117, 'contract_name': 'dublin', 'name': 'HANOVER QUAY EAST', 'address': 'Hanover Quay East', 'position': {'lat': 53.343653, 'lng': -6.231755}, 'banking': False, 'bonus': False, 'bike_stands': 40, 'available_bike_stands': 32, 'available_bikes': 7, 'status': 'OPEN', 'last_update': 1677231037000}
# 2023-02-24 09:39:49,553 INFO sqlalchemy.engine.Engine insert into availability values (%s,%s,%s,%s)
# 2023-02-24 09:39:49,554 INFO sqlalchemy.engine.Engine [raw sql] (117, 7, 32, 1677231565.537707)
# 2023-02-24 09:39:49,690 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 8, 'contract_name': 'dublin', 'name': 'CUSTOM HOUSE QUAY', 'address': 'Custom House Quay', 'position': {'lat': 53.347884, 'lng': -6.248048}, 'banking': False, 'bonus': False, 'bike_stands': 30, 'available_bike_stands': 10, 'available_bikes': 20, 'status': 'OPEN', 'last_update': 1677231327000}
# 2023-02-24 09:39:49,994 INFO sqlalchemy.engine.Engine insert into availability values (%s,%s,%s,%s)
# 2023-02-24 09:39:49,995 INFO sqlalchemy.engine.Engine [raw sql] (8, 20, 10, 1677231565.537707)
# 2023-02-24 09:39:50,106 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 27, 'contract_name': 'dublin', 'name': 'MOLESWORTH STREET', 'address': 'Molesworth Street', 'position': {'lat': 53.341288, 'lng': -6.258117}, 'banking': False, 'bonus': False, 'bike_stands': 20, 'available_bike_stands': 14, 'available_bikes': 6, 'status': 'OPEN', 'last_update': 1677231445000}
# 2023-02-24 09:39:50,412 INFO sqlalchemy.engine.Engine insert into availability values (%s,%s,%s,%s)
# 2023-02-24 09:39:50,413 INFO sqlalchemy.engine.Engine [raw sql] (27, 6, 14, 1677231565.537707)
# 2023-02-24 09:39:50,526 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 16, 'contract_name': 'dublin', 'name': 'GEORGES QUAY', 'address': 'Georges Quay', 'position': {'lat': 53.347508, 'lng': -6.252192}, 'banking': False, 'bonus': False, 'bike_stands': 20, 'available_bike_stands': 5, 'available_bikes': 14, 'status': 'OPEN', 'last_update': 1677231261000}
# 2023-02-24 09:39:50,750 INFO sqlalchemy.engine.Engine insert into availability values (%s,%s,%s,%s)
# 2023-02-24 09:39:50,751 INFO sqlalchemy.engine.Engine [raw sql] (16, 14, 5, 1677231565.537707)
# 2023-02-24 09:39:50,935 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 96, 'contract_name': 'dublin', 'name': 'KILMAINHAM LANE', 'address': 'Kilmainham Lane', 'position': {'lat': 53.341805, 'lng': -6.305085}, 'banking': False, 'bonus': False, 'bike_stands': 30, 'available_bike_stands': 21, 'available_bikes': 8, 'status': 'OPEN', 'last_update': 1677230962000}
# 2023-02-24 09:39:51,172 INFO sqlalchemy.engine.Engine insert into availability values (%s,%s,%s,%s)
# 2023-02-24 09:39:51,174 INFO sqlalchemy.engine.Engine [raw sql] (96, 8, 21, 1677231565.537707)
# 2023-02-24 09:39:51,333 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 82, 'contract_name': 'dublin', 'name': 'MOUNT BROWN', 'address': 'Mount Brown', 'position': {'lat': 53.341645, 'lng': -6.29719}, 'banking': False, 'bonus': False, 'bike_stands': 22, 'available_bike_stands': 17, 'available_bikes': 5, 'status': 'OPEN', 'last_update': 1677230948000}
# 2023-02-24 09:39:51,596 INFO sqlalchemy.engine.Engine insert into availability values (%s,%s,%s,%s)
# 2023-02-24 09:39:51,597 INFO sqlalchemy.engine.Engine [raw sql] (82, 5, 17, 1677231565.537707)
# 2023-02-24 09:39:51,690 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 76, 'contract_name': 'dublin', 'name': 'MARKET STREET SOUTH', 'address': 'Market Street South', 'position': {'lat': 53.342296, 'lng': -6.287661}, 'banking': False, 'bonus': False, 'bike_stands': 38, 'available_bike_stands': 38, 'available_bikes': 0, 'status': 'OPEN', 'last_update': 1677231157000}
# 2023-02-24 09:39:51,987 INFO sqlalchemy.engine.Engine insert into availability values (%s,%s,%s,%s)
# 2023-02-24 09:39:51,988 INFO sqlalchemy.engine.Engine [raw sql] (76, 0, 38, 1677231565.537707)
# 2023-02-24 09:39:52,180 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 71, 'contract_name': 'dublin', 'name': 'KEVIN STREET', 'address': 'Kevin Street', 'position': {'lat': 53.337757, 'lng': -6.267699}, 'banking': False, 'bonus': False, 'bike_stands': 40, 'available_bike_stands': 39, 'available_bikes': 1, 'status': 'OPEN', 'last_update': 1677231357000}
# 2023-02-24 09:39:52,705 INFO sqlalchemy.engine.Engine insert into availability values (%s,%s,%s,%s)
# 2023-02-24 09:39:52,706 INFO sqlalchemy.engine.Engine [raw sql] (71, 1, 39, 1677231565.537707)
# 2023-02-24 09:39:52,799 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 79, 'contract_name': 'dublin', 'name': 'ECCLES STREET EAST', 'address': 'Eccles Street East', 'position': {'lat': 53.358115, 'lng': -6.265601}, 'banking': False, 'bonus': False, 'bike_stands': 27, 'available_bike_stands': 20, 'available_bikes': 7, 'status': 'OPEN', 'last_update': 1677231371000}
# 2023-02-24 09:39:53,242 INFO sqlalchemy.engine.Engine insert into availability values (%s,%s,%s,%s)
# 2023-02-24 09:39:53,243 INFO sqlalchemy.engine.Engine [raw sql] (79, 7, 20, 1677231565.537707)
# 2023-02-24 09:39:53,425 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 69, 'contract_name': 'dublin', 'name': 'GRAND CANAL DOCK', 'address': 'Grand Canal Dock', 'position': {'lat': 53.342638, 'lng': -6.238695}, 'banking': False, 'bonus': False, 'bike_stands': 40, 'available_bike_stands': 19, 'available_bikes': 21, 'status': 'OPEN', 'last_update': 1677231485000}
# 2023-02-24 09:39:53,649 INFO sqlalchemy.engine.Engine insert into availability values (%s,%s,%s,%s)
# 2023-02-24 09:39:53,651 INFO sqlalchemy.engine.Engine [raw sql] (69, 21, 19, 1677231565.537707)
# 2023-02-24 09:39:53,762 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 25, 'contract_name': 'dublin', 'name': 'MERRION SQUARE EAST', 'address': 'Merrion Square East', 'position': {'lat': 53.339434, 'lng': -6.246548}, 'banking': False, 'bonus': False, 'bike_stands': 30, 'available_bike_stands': 15, 'available_bikes': 15, 'status': 'OPEN', 'last_update': 1677230978000}
# 2023-02-24 09:39:54,081 INFO sqlalchemy.engine.Engine insert into availability values (%s,%s,%s,%s)
# 2023-02-24 09:39:54,081 INFO sqlalchemy.engine.Engine [raw sql] (25, 15, 15, 1677231565.537707)
# 2023-02-24 09:39:54,175 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 51, 'contract_name': 'dublin', 'name': 'YORK STREET WEST', 'address': 'York Street West', 'position': {'lat': 53.339334, 'lng': -6.264699}, 'banking': False, 'bonus': False, 'bike_stands': 40, 'available_bike_stands': 36, 'available_bikes': 4, 'status': 'OPEN', 'last_update': 1677231096000}
# 2023-02-24 09:39:54,476 INFO sqlalchemy.engine.Engine insert into availability values (%s,%s,%s,%s)
# 2023-02-24 09:39:54,477 INFO sqlalchemy.engine.Engine [raw sql] (51, 4, 36, 1677231565.537707)
# 2023-02-24 09:39:54,629 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 37, 'contract_name': 'dublin', 'name': "ST. STEPHEN'S GREEN SOUTH", 'address': "St. Stephen's Green South", 'position': {'lat': 53.337494, 'lng': -6.26199}, 'banking': True, 'bonus': False, 'bike_stands': 30, 'available_bike_stands': 23, 'available_bikes': 7, 'status': 'OPEN', 'last_update': 1677231364000}
# 2023-02-24 09:39:54,815 INFO sqlalchemy.engine.Engine insert into availability values (%s,%s,%s,%s)
# 2023-02-24 09:39:54,816 INFO sqlalchemy.engine.Engine [raw sql] (37, 7, 23, 1677231565.537707)
# 2023-02-24 09:39:54,912 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 59, 'contract_name': 'dublin', 'name': 'DENMARK STREET GREAT', 'address': 'Denmark Street Great', 'position': {'lat': 53.35561, 'lng': -6.261397}, 'banking': False, 'bonus': False, 'bike_stands': 20, 'available_bike_stands': 11, 'available_bikes': 9, 'status': 'OPEN', 'last_update': 1677231462000}
# 2023-02-24 09:39:55,224 INFO sqlalchemy.engine.Engine insert into availability values (%s,%s,%s,%s)
# 2023-02-24 09:39:55,226 INFO sqlalchemy.engine.Engine [raw sql] (59, 9, 11, 1677231565.537707)
# 2023-02-24 09:39:55,337 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 95, 'contract_name': 'dublin', 'name': 'ROYAL HOSPITAL', 'address': 'Royal Hospital', 'position': {'lat': 53.343897, 'lng': -6.29706}, 'banking': False, 'bonus': False, 'bike_stands': 40, 'available_bike_stands': 28, 'available_bikes': 12, 'status': 'OPEN', 'last_update': 1677231467000}
# 2023-02-24 09:39:55,654 INFO sqlalchemy.engine.Engine insert into availability values (%s,%s,%s,%s)
# 2023-02-24 09:39:55,656 INFO sqlalchemy.engine.Engine [raw sql] (95, 12, 28, 1677231565.537707)
# 2023-02-24 09:39:55,749 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 94, 'contract_name': 'dublin', 'name': 'HEUSTON STATION (CAR PARK)', 'address': 'Heuston Station (Car Park)', 'position': {'lat': 53.346985, 'lng': -6.297804}, 'banking': False, 'bonus': False, 'bike_stands': 40, 'available_bike_stands': 27, 'available_bikes': 13, 'status': 'OPEN', 'last_update': 1677231462000}
# 2023-02-24 09:39:55,962 INFO sqlalchemy.engine.Engine insert into availability values (%s,%s,%s,%s)
# 2023-02-24 09:39:55,964 INFO sqlalchemy.engine.Engine [raw sql] (94, 13, 27, 1677231565.537707)
# 2023-02-24 09:39:56,178 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 105, 'contract_name': 'dublin', 'name': 'GRANGEGORMAN LOWER (NORTH)', 'address': 'Grangegorman Lower (North)', 'position': {'lat': 53.355954, 'lng': -6.278378}, 'banking': False, 'bonus': False, 'bike_stands': 36, 'available_bike_stands': 16, 'available_bikes': 19, 'status': 'OPEN', 'last_update': 1677230956000}
# 2023-02-24 09:39:56,386 INFO sqlalchemy.engine.Engine insert into availability values (%s,%s,%s,%s)
# 2023-02-24 09:39:56,386 INFO sqlalchemy.engine.Engine [raw sql] (105, 19, 16, 1677231565.537707)
# 2023-02-24 09:39:56,576 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 36, 'contract_name': 'dublin', 'name': "ST. STEPHEN'S GREEN EAST", 'address': "St. Stephen's Green East", 'position': {'lat': 53.337824, 'lng': -6.256035}, 'banking': False, 'bonus': False, 'bike_stands': 40, 'available_bike_stands': 31, 'available_bikes': 9, 'status': 'OPEN', 'last_update': 1677230985000}
# 2023-02-24 09:39:56,807 INFO sqlalchemy.engine.Engine insert into availability values (%s,%s,%s,%s)
# 2023-02-24 09:39:56,808 INFO sqlalchemy.engine.Engine [raw sql] (36, 9, 31, 1677231565.537707)
# 2023-02-24 09:39:56,939 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 93, 'contract_name': 'dublin', 'name': 'HEUSTON STATION (CENTRAL)', 'address': 'Heuston Station (Central)', 'position': {'lat': 53.346603, 'lng': -6.296924}, 'banking': False, 'bonus': False, 'bike_stands': 40, 'available_bike_stands': 20, 'available_bikes': 19, 'status': 'OPEN', 'last_update': 1677231358000}
# 2023-02-24 09:39:57,467 INFO sqlalchemy.engine.Engine insert into availability values (%s,%s,%s,%s)
# 2023-02-24 09:39:57,468 INFO sqlalchemy.engine.Engine [raw sql] (93, 19, 20, 1677231565.537707)
# 2023-02-24 09:39:57,619 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 22, 'contract_name': 'dublin', 'name': 'TOWNSEND STREET', 'address': 'Townsend Street', 'position': {'lat': 53.345922, 'lng': -6.254614}, 'banking': False, 'bonus': False, 'bike_stands': 20, 'available_bike_stands': 16, 'available_bikes': 3, 'status': 'OPEN', 'last_update': 1677231478000}
# 2023-02-24 09:39:57,882 INFO sqlalchemy.engine.Engine insert into availability values (%s,%s,%s,%s)
# 2023-02-24 09:39:57,883 INFO sqlalchemy.engine.Engine [raw sql] (22, 3, 16, 1677231565.537707)
# 2023-02-24 09:39:57,990 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 50, 'contract_name': 'dublin', 'name': 'GEORGES LANE', 'address': "George's Lane", 'position': {'lat': 53.35023, 'lng': -6.279696}, 'banking': False, 'bonus': False, 'bike_stands': 40, 'available_bike_stands': 37, 'available_bikes': 3, 'status': 'OPEN', 'last_update': 1677231304000}
# 2023-02-24 09:39:58,374 INFO sqlalchemy.engine.Engine insert into availability values (%s,%s,%s,%s)
# 2023-02-24 09:39:58,375 INFO sqlalchemy.engine.Engine [raw sql] (50, 3, 37, 1677231565.537707)
# 2023-02-24 09:39:58,469 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 110, 'contract_name': 'dublin', 'name': 'PHIBSBOROUGH ROAD', 'address': 'Phibsborough Road', 'position': {'lat': 53.356307, 'lng': -6.273717}, 'banking': False, 'bonus': False, 'bike_stands': 40, 'available_bike_stands': 27, 'available_bikes': 13, 'status': 'OPEN', 'last_update': 1677231207000}
# 2023-02-24 09:39:58,802 INFO sqlalchemy.engine.Engine insert into availability values (%s,%s,%s,%s)
# 2023-02-24 09:39:58,803 INFO sqlalchemy.engine.Engine [raw sql] (110, 13, 27, 1677231565.537707)
# 2023-02-24 09:39:58,899 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 12, 'contract_name': 'dublin', 'name': 'ECCLES STREET', 'address': 'Eccles Street', 'position': {'lat': 53.359246, 'lng': -6.269779}, 'banking': False, 'bonus': False, 'bike_stands': 20, 'available_bike_stands': 20, 'available_bikes': 0, 'status': 'OPEN', 'last_update': 1677231444000}
# 2023-02-24 09:39:59,127 INFO sqlalchemy.engine.Engine insert into availability values (%s,%s,%s,%s)
# 2023-02-24 09:39:59,129 INFO sqlalchemy.engine.Engine [raw sql] (12, 0, 20, 1677231565.537707)
# 2023-02-24 09:39:59,334 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 34, 'contract_name': 'dublin', 'name': 'PORTOBELLO HARBOUR', 'address': 'Portobello Harbour', 'position': {'lat': 53.330362, 'lng': -6.265163}, 'banking': False, 'bonus': False, 'bike_stands': 30, 'available_bike_stands': 22, 'available_bikes': 8, 'status': 'OPEN', 'last_update': 1677231493000}
# 2023-02-24 09:39:59,567 INFO sqlalchemy.engine.Engine insert into availability values (%s,%s,%s,%s)
# 2023-02-24 09:39:59,568 INFO sqlalchemy.engine.Engine [raw sql] (34, 8, 22, 1677231565.537707)
# 2023-02-24 09:39:59,716 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 78, 'contract_name': 'dublin', 'name': 'MATER HOSPITAL', 'address': 'Mater Hospital', 'position': {'lat': 53.359967, 'lng': -6.264828}, 'banking': False, 'bonus': False, 'bike_stands': 40, 'available_bike_stands': 31, 'available_bikes': 9, 'status': 'OPEN', 'last_update': 1677231018000}
# 2023-02-24 09:39:59,963 INFO sqlalchemy.engine.Engine insert into availability values (%s,%s,%s,%s)
# 2023-02-24 09:39:59,965 INFO sqlalchemy.engine.Engine [raw sql] (78, 9, 31, 1677231565.537707)
# 2023-02-24 09:40:00,058 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 2, 'contract_name': 'dublin', 'name': 'BLESSINGTON STREET', 'address': 'Blessington Street', 'position': {'lat': 53.356769, 'lng': -6.26814}, 'banking': False, 'bonus': False, 'bike_stands': 20, 'available_bike_stands': 18, 'available_bikes': 2, 'status': 'OPEN', 'last_update': 1677231487000}
# 2023-02-24 09:40:00,381 INFO sqlalchemy.engine.Engine insert into availability values (%s,%s,%s,%s)
# 2023-02-24 09:40:00,383 INFO sqlalchemy.engine.Engine [raw sql] (2, 2, 18, 1677231565.537707)
# 2023-02-24 09:40:00,489 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 75, 'contract_name': 'dublin', 'name': 'JAMES STREET', 'address': 'James Street', 'position': {'lat': 53.343456, 'lng': -6.287409}, 'banking': False, 'bonus': False, 'bike_stands': 40, 'available_bike_stands': 38, 'available_bikes': 2, 'status': 'OPEN', 'last_update': 1677231313000}
# 2023-02-24 09:40:00,899 INFO sqlalchemy.engine.Engine insert into availability values (%s,%s,%s,%s)
# 2023-02-24 09:40:00,901 INFO sqlalchemy.engine.Engine [raw sql] (75, 2, 38, 1677231565.537707)
# 2023-02-24 09:40:01,004 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 507, 'contract_name': 'dublin', 'name': 'ORIEL STREET TEST TERMINAL', 'address': 'JCDecaux Ireland, 52 Oriel Street Lower, Dublin 1', 'position': {'lat': 53.35463, 'lng': -6.242615}, 'banking': False, 'bonus': False, 'bike_stands': 1, 'available_bike_stands': 0, 'available_bikes': 1, 'status': 'OPEN', 'last_update': 1675786128000}
# 2023-02-24 09:40:01,205 INFO sqlalchemy.engine.Engine insert into availability values (%s,%s,%s,%s)
# ...
# 2023-02-24 09:52:10,430 INFO sqlalchemy.engine.Engine [raw sql] (27, 6, 14, 1677232304.956334)
# 2023-02-24 09:52:10,614 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 16, 'contract_name': 'dublin', 'name': 'GEORGES QUAY', 'address': 'Georges Quay', 'position': {'lat': 53.347508, 'lng': -6.252192}, 'banking': False, 'bonus': False, 'bike_stands': 20, 'available_bike_stands': 5, 'available_bikes': 14, 'status': 'OPEN', 'last_update': 1677231261000}
# 2023-02-24 09:52:10,869 INFO sqlalchemy.engine.Engine insert into availability values (%s,%s,%s,%s)
# 2023-02-24 09:52:10,870 INFO sqlalchemy.engine.Engine [raw sql] (16, 14, 5, 1677232304.956334)
# 2023-02-24 09:52:10,960 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 96, 'contract_name': 'dublin', 'name': 'KILMAINHAM LANE', 'address': 'Kilmainham Lane', 'position': {'lat': 53.341805, 'lng': -6.305085}, 'banking': False, 'bonus': False, 'bike_stands': 30, 'available_bike_stands': 21, 'available_bikes': 8, 'status': 'OPEN', 'last_update': 1677230962000}
# 2023-02-24 09:52:11,268 INFO sqlalchemy.engine.Engine insert into availability values (%s,%s,%s,%s)
# 2023-02-24 09:52:11,269 INFO sqlalchemy.engine.Engine [raw sql] (96, 8, 21, 1677232304.956334)
# 2023-02-24 09:52:11,359 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 82, 'contract_name': 'dublin', 'name': 'MOUNT BROWN', 'address': 'Mount Brown', 'position': {'lat': 53.341645, 'lng': -6.29719}, 'banking': False, 'bonus': False, 'bike_stands': 22, 'available_bike_stands': 17, 'available_bikes': 5, 'status': 'OPEN', 'last_update': 1677230948000}
# 2023-02-24 09:52:11,662 INFO sqlalchemy.engine.Engine insert into availability values (%s,%s,%s,%s)
# 2023-02-24 09:52:11,663 INFO sqlalchemy.engine.Engine [raw sql] (82, 5, 17, 1677232304.956334)
# 2023-02-24 09:52:11,793 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 76, 'contract_name': 'dublin', 'name': 'MARKET STREET SOUTH', 'address': 'Market Street South', 'position': {'lat': 53.342296, 'lng': -6.287661}, 'banking': False, 'bonus': False, 'bike_stands': 38, 'available_bike_stands': 38, 'available_bikes': 0, 'status': 'OPEN', 'last_update': 1677231157000}
# 2023-02-24 09:52:12,019 INFO sqlalchemy.engine.Engine insert into availability values (%s,%s,%s,%s)
# 2023-02-24 09:52:12,019 INFO sqlalchemy.engine.Engine [raw sql] (76, 0, 38, 1677232304.956334)
# 2023-02-24 09:52:12,139 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 71, 'contract_name': 'dublin', 'name': 'KEVIN STREET', 'address': 'Kevin Street', 'position': {'lat': 53.337757, 'lng': -6.267699}, 'banking': False, 'bonus': False, 'bike_stands': 40, 'available_bike_stands': 39, 'available_bikes': 1, 'status': 'OPEN', 'last_update': 1677231357000}
# 2023-02-24 09:52:12,407 INFO sqlalchemy.engine.Engine insert into availability values (%s,%s,%s,%s)
# 2023-02-24 09:52:12,407 INFO sqlalchemy.engine.Engine [raw sql] (71, 1, 39, 1677232304.956334)
# 2023-02-24 09:52:12,521 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 79, 'contract_name': 'dublin', 'name': 'ECCLES STREET EAST', 'address': 'Eccles Street East', 'position': {'lat': 53.358115, 'lng': -6.265601}, 'banking': False, 'bonus': False, 'bike_stands': 27, 'available_bike_stands': 20, 'available_bikes': 7, 'status': 'OPEN', 'last_update': 1677231371000}
# 2023-02-24 09:52:12,840 INFO sqlalchemy.engine.Engine insert into availability values (%s,%s,%s,%s)
# 2023-02-24 09:52:12,842 INFO sqlalchemy.engine.Engine [raw sql] (79, 7, 20, 1677232304.956334)
# 2023-02-24 09:52:12,937 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 69, 'contract_name': 'dublin', 'name': 'GRAND CANAL DOCK', 'address': 'Grand Canal Dock', 'position': {'lat': 53.342638, 'lng': -6.238695}, 'banking': False, 'bonus': False, 'bike_stands': 40, 'available_bike_stands': 19, 'available_bikes': 21, 'status': 'OPEN', 'last_update': 1677231485000}
# 2023-02-24 09:52:13,152 INFO sqlalchemy.engine.Engine insert into availability values (%s,%s,%s,%s)
# 2023-02-24 09:52:13,153 INFO sqlalchemy.engine.Engine [raw sql] (69, 21, 19, 1677232304.956334)
# 2023-02-24 09:52:13,367 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 25, 'contract_name': 'dublin', 'name': 'MERRION SQUARE EAST', 'address': 'Merrion Square East', 'position': {'lat': 53.339434, 'lng': -6.246548}, 'banking': False, 'bonus': False, 'bike_stands': 30, 'available_bike_stands': 15, 'available_bikes': 15, 'status': 'OPEN', 'last_update': 1677230978000}
# 2023-02-24 09:52:13,580 INFO sqlalchemy.engine.Engine insert into availability values (%s,%s,%s,%s)
# 2023-02-24 09:52:13,582 INFO sqlalchemy.engine.Engine [raw sql] (25, 15, 15, 1677232304.956334)
# 2023-02-24 09:52:13,770 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 51, 'contract_name': 'dublin', 'name': 'YORK STREET WEST', 'address': 'York Street West', 'position': {'lat': 53.339334, 'lng': -6.264699}, 'banking': False, 'bonus': False, 'bike_stands': 40, 'available_bike_stands': 36, 'available_bikes': 4, 'status': 'OPEN', 'last_update': 1677231096000}
# 2023-02-24 09:52:13,986 INFO sqlalchemy.engine.Engine insert into availability values (%s,%s,%s,%s)
# 2023-02-24 09:52:13,987 INFO sqlalchemy.engine.Engine [raw sql] (51, 4, 36, 1677232304.956334)
# 2023-02-24 09:52:14,088 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 37, 'contract_name': 'dublin', 'name': "ST. STEPHEN'S GREEN SOUTH", 'address': "St. Stephen's Green South", 'position': {'lat': 53.337494, 'lng': -6.26199}, 'banking': True, 'bonus': False, 'bike_stands': 30, 'available_bike_stands': 23, 'available_bikes': 7, 'status': 'OPEN', 'last_update': 1677231364000}
# 2023-02-24 09:52:14,613 INFO sqlalchemy.engine.Engine insert into availability values (%s,%s,%s,%s)
# 2023-02-24 09:52:14,614 INFO sqlalchemy.engine.Engine [raw sql] (37, 7, 23, 1677232304.956334)
# 2023-02-24 09:52:14,709 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 59, 'contract_name': 'dublin', 'name': 'DENMARK STREET GREAT', 'address': 'Denmark Street Great', 'position': {'lat': 53.35561, 'lng': -6.261397}, 'banking': False, 'bonus': False, 'bike_stands': 20, 'available_bike_stands': 11, 'available_bikes': 9, 'status': 'OPEN', 'last_update': 1677231462000}
# 2023-02-24 09:52:15,241 INFO sqlalchemy.engine.Engine insert into availability values (%s,%s,%s,%s)
# 2023-02-24 09:52:15,242 INFO sqlalchemy.engine.Engine [raw sql] (59, 9, 11, 1677232304.956334)
# 2023-02-24 09:52:15,462 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 95, 'contract_name': 'dublin', 'name': 'ROYAL HOSPITAL', 'address': 'Royal Hospital', 'position': {'lat': 53.343897, 'lng': -6.29706}, 'banking': False, 'bonus': False, 'bike_stands': 40, 'available_bike_stands': 28, 'available_bikes': 12, 'status': 'OPEN', 'last_update': 1677231467000}
# 2023-02-24 09:52:15,656 INFO sqlalchemy.engine.Engine insert into availability values (%s,%s,%s,%s)
# 2023-02-24 09:52:15,657 INFO sqlalchemy.engine.Engine [raw sql] (95, 12, 28, 1677232304.956334)
# 2023-02-24 09:52:15,862 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 94, 'contract_name': 'dublin', 'name': 'HEUSTON STATION (CAR PARK)', 'address': 'Heuston Station (Car Park)', 'position': {'lat': 53.346985, 'lng': -6.297804}, 'banking': False, 'bonus': False, 'bike_stands': 40, 'available_bike_stands': 27, 'available_bikes': 13, 'status': 'OPEN', 'last_update': 1677231462000}
# 2023-02-24 09:52:16,083 INFO sqlalchemy.engine.Engine insert into availability values (%s,%s,%s,%s)
# 2023-02-24 09:52:16,084 INFO sqlalchemy.engine.Engine [raw sql] (94, 13, 27, 1677232304.956334)
# 2023-02-24 09:52:16,180 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 105, 'contract_name': 'dublin', 'name': 'GRANGEGORMAN LOWER (NORTH)', 'address': 'Grangegorman Lower (North)', 'position': {'lat': 53.355954, 'lng': -6.278378}, 'banking': False, 'bonus': False, 'bike_stands': 36, 'available_bike_stands': 16, 'available_bikes': 19, 'status': 'OPEN', 'last_update': 1677230956000}
# 2023-02-24 09:52:16,514 INFO sqlalchemy.engine.Engine insert into availability values (%s,%s,%s,%s)
# 2023-02-24 09:52:16,516 INFO sqlalchemy.engine.Engine [raw sql] (105, 19, 16, 1677232304.956334)
# 2023-02-24 09:52:16,613 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 36, 'contract_name': 'dublin', 'name': "ST. STEPHEN'S GREEN EAST", 'address': "St. Stephen's Green East", 'position': {'lat': 53.337824, 'lng': -6.256035}, 'banking': False, 'bonus': False, 'bike_stands': 40, 'available_bike_stands': 31, 'available_bikes': 9, 'status': 'OPEN', 'last_update': 1677230985000}
# 2023-02-24 09:52:16,814 INFO sqlalchemy.engine.Engine insert into availability values (%s,%s,%s,%s)
# 2023-02-24 09:52:16,815 INFO sqlalchemy.engine.Engine [raw sql] (36, 9, 31, 1677232304.956334)
# 2023-02-24 09:52:17,037 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 93, 'contract_name': 'dublin', 'name': 'HEUSTON STATION (CENTRAL)', 'address': 'Heuston Station (Central)', 'position': {'lat': 53.346603, 'lng': -6.296924}, 'banking': False, 'bonus': False, 'bike_stands': 40, 'available_bike_stands': 20, 'available_bikes': 19, 'status': 'OPEN', 'last_update': 1677231358000}
# 2023-02-24 09:52:17,236 INFO sqlalchemy.engine.Engine insert into availability values (%s,%s,%s,%s)
# 2023-02-24 09:52:17,236 INFO sqlalchemy.engine.Engine [raw sql] (93, 19, 20, 1677232304.956334)
# 2023-02-24 09:52:17,345 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 22, 'contract_name': 'dublin', 'name': 'TOWNSEND STREET', 'address': 'Townsend Street', 'position': {'lat': 53.345922, 'lng': -6.254614}, 'banking': False, 'bonus': False, 'bike_stands': 20, 'available_bike_stands': 16, 'available_bikes': 3, 'status': 'OPEN', 'last_update': 1677231478000}
# 2023-02-24 09:52:17,662 INFO sqlalchemy.engine.Engine insert into availability values (%s,%s,%s,%s)
# 2023-02-24 09:52:17,663 INFO sqlalchemy.engine.Engine [raw sql] (22, 3, 16, 1677232304.956334)
# 2023-02-24 09:52:17,754 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 50, 'contract_name': 'dublin', 'name': 'GEORGES LANE', 'address': "George's Lane", 'position': {'lat': 53.35023, 'lng': -6.279696}, 'banking': False, 'bonus': False, 'bike_stands': 40, 'available_bike_stands': 37, 'available_bikes': 3, 'status': 'OPEN', 'last_update': 1677231304000}
# 2023-02-24 09:52:17,955 INFO sqlalchemy.engine.Engine insert into availability values (%s,%s,%s,%s)
# 2023-02-24 09:52:17,955 INFO sqlalchemy.engine.Engine [raw sql] (50, 3, 37, 1677232304.956334)
# 2023-02-24 09:52:18,084 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 110, 'contract_name': 'dublin', 'name': 'PHIBSBOROUGH ROAD', 'address': 'Phibsborough Road', 'position': {'lat': 53.356307, 'lng': -6.273717}, 'banking': False, 'bonus': False, 'bike_stands': 40, 'available_bike_stands': 27, 'available_bikes': 13, 'status': 'OPEN', 'last_update': 1677231207000}
# 2023-02-24 09:52:18,276 INFO sqlalchemy.engine.Engine insert into availability values (%s,%s,%s,%s)
# 2023-02-24 09:52:18,277 INFO sqlalchemy.engine.Engine [raw sql] (110, 13, 27, 1677232304.956334)
# 2023-02-24 09:52:18,370 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 12, 'contract_name': 'dublin', 'name': 'ECCLES STREET', 'address': 'Eccles Street', 'position': {'lat': 53.359246, 'lng': -6.269779}, 'banking': False, 'bonus': False, 'bike_stands': 20, 'available_bike_stands': 20, 'available_bikes': 0, 'status': 'OPEN', 'last_update': 1677231444000}
# 2023-02-24 09:52:18,702 INFO sqlalchemy.engine.Engine insert into availability values (%s,%s,%s,%s)
# 2023-02-24 09:52:18,703 INFO sqlalchemy.engine.Engine [raw sql] (12, 0, 20, 1677232304.956334)
# 2023-02-24 09:52:18,795 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 34, 'contract_name': 'dublin', 'name': 'PORTOBELLO HARBOUR', 'address': 'Portobello Harbour', 'position': {'lat': 53.330362, 'lng': -6.265163}, 'banking': False, 'bonus': False, 'bike_stands': 30, 'available_bike_stands': 22, 'available_bikes': 8, 'status': 'OPEN', 'last_update': 1677231493000}
# 2023-02-24 09:52:19,002 INFO sqlalchemy.engine.Engine insert into availability values (%s,%s,%s,%s)
# 2023-02-24 09:52:19,002 INFO sqlalchemy.engine.Engine [raw sql] (34, 8, 22, 1677232304.956334)
# 2023-02-24 09:52:19,137 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 78, 'contract_name': 'dublin', 'name': 'MATER HOSPITAL', 'address': 'Mater Hospital', 'position': {'lat': 53.359967, 'lng': -6.264828}, 'banking': False, 'bonus': False, 'bike_stands': 40, 'available_bike_stands': 31, 'available_bikes': 9, 'status': 'OPEN', 'last_update': 1677231018000}
# 2023-02-24 09:52:19,355 INFO sqlalchemy.engine.Engine insert into availability values (%s,%s,%s,%s)
# 2023-02-24 09:52:19,356 INFO sqlalchemy.engine.Engine [raw sql] (78, 9, 31, 1677232304.956334)
# 2023-02-24 09:52:19,449 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 2, 'contract_name': 'dublin', 'name': 'BLESSINGTON STREET', 'address': 'Blessington Street', 'position': {'lat': 53.356769, 'lng': -6.26814}, 'banking': False, 'bonus': False, 'bike_stands': 20, 'available_bike_stands': 18, 'available_bikes': 2, 'status': 'OPEN', 'last_update': 1677231487000}
# 2023-02-24 09:52:19,750 INFO sqlalchemy.engine.Engine insert into availability values (%s,%s,%s,%s)
# 2023-02-24 09:52:19,751 INFO sqlalchemy.engine.Engine [raw sql] (2, 2, 18, 1677232304.956334)
# 2023-02-24 09:52:19,844 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 75, 'contract_name': 'dublin', 'name': 'JAMES STREET', 'address': 'James Street', 'position': {'lat': 53.343456, 'lng': -6.287409}, 'banking': False, 'bonus': False, 'bike_stands': 40, 'available_bike_stands': 38, 'available_bikes': 2, 'status': 'OPEN', 'last_update': 1677231313000}
# 2023-02-24 09:52:20,051 INFO sqlalchemy.engine.Engine insert into availability values (%s,%s,%s,%s)
# 2023-02-24 09:52:20,051 INFO sqlalchemy.engine.Engine [raw sql] (75, 2, 38, 1677232304.956334)
# 2023-02-24 09:52:20,181 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 507, 'contract_name': 'dublin', 'name': 'ORIEL STREET TEST TERMINAL', 'address': 'JCDecaux Ireland, 52 Oriel Street Lower, Dublin 1', 'position': {'lat': 53.35463, 'lng': -6.242615}, 'banking': False, 'bonus': False, 'bike_stands': 1, 'available_bike_stands': 0, 'available_bikes': 1, 'status': 'OPEN', 'last_update': 1675786128000}
# 2023-02-24 09:52:20,372 INFO sqlalchemy.engine.Engine insert into availability values (%s,%s,%s,%s)
# 2023-02-24 09:52:20,372 INFO sqlalchemy.engine.Engine [raw sql] (507, 1, 0, 1677232304.956334)
# 2023-02-24 09:52:20,463 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 111, 'contract_name': 'dublin', 'name': 'MOUNTJOY SQUARE EAST', 'address': 'Mountjoy Square East', 'position': {'lat': 53.356717, 'lng': -6.256359}, 'banking': False, 'bonus': False, 'bike_stands': 40, 'available_bike_stands': 33, 'available_bikes': 7, 'status': 'OPEN', 'last_update': 1677231308000}
# 2023-02-24 09:52:20,798 INFO sqlalchemy.engine.Engine insert into availability values (%s,%s,%s,%s)
# 2023-02-24 09:52:20,799 INFO sqlalchemy.engine.Engine [raw sql] (111, 7, 33, 1677232304.956334)
# 2023-02-24 09:52:20,890 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 26, 'contract_name': 'dublin', 'name': 'MERRION SQUARE WEST', 'address': 'Merrion Square West', 'position': {'lat': 53.339764, 'lng': -6.251988}, 'banking': True, 'bonus': False, 'bike_stands': 20, 'available_bike_stands': 9, 'available_bikes': 11, 'status': 'OPEN', 'last_update': 1677231392000}
# 2023-02-24 09:52:21,099 INFO sqlalchemy.engine.Engine insert into availability values (%s,%s,%s,%s)
# 2023-02-24 09:52:21,100 INFO sqlalchemy.engine.Engine [raw sql] (26, 11, 9, 1677232304.956334)
# 2023-02-24 09:52:21,229 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 65, 'contract_name': 'dublin', 'name': 'CONVENTION CENTRE', 'address': 'Convention Centre', 'position': {'lat': 53.34744, 'lng': -6.238523}, 'banking': True, 'bonus': False, 'bike_stands': 40, 'available_bike_stands': 20, 'available_bikes': 20, 'status': 'OPEN', 'last_update': 1677231505000}
# 2023-02-24 09:52:21,418 INFO sqlalchemy.engine.Engine insert into availability values (%s,%s,%s,%s)
# 2023-02-24 09:52:21,418 INFO sqlalchemy.engine.Engine [raw sql] (65, 20, 20, 1677232304.956334)
# 2023-02-24 09:52:21,510 INFO sqlalchemy.engine.Engine COMMIT
