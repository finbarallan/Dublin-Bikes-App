# %%
import requests
import json
import sqlalchemy as sqla
from sqlalchemy import create_engine

URI = "dublinbikesdb.ctnqnsdsyxei.us-east-1.rds.amazonaws.com"
PASSWORD = "Grouptwentysix"
PORT = "3306"
DB = "dbbikes"
USER = "Group26"

engine = create_engine("mysql+mysqldb://{}:{}@{}:{}/{}".format(USER, PASSWORD, URI, PORT, DB), echo=True)

def stations_to_db(text):
    stations = json.loads(text)
    print(type(stations), len(stations)) 
    for station in stations:
        print (station)
        vals = (station.get('address'), int(station.get('banking')), station.get('bike_stands'), int(station.get('bonus')), station.get('contract_name'), station.get('name'), station.get('number'), station.get('position').get('lat'), station.get('position').get('lng'), station.get('status'))
        engine.execute("insert into station values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)",vals)
    return

url = "https://api.jcdecaux.com/vls/v1/stations?contract=Dublin&apiKey=a572dc37b128fb280c9e1621093640367863e160"
response = requests.get(url)
stations_to_db(response.text)
# Out:
# <class 'list'> 114
# {'number': 42, 'contract_name': 'dublin', 'name': 'SMITHFIELD NORTH', 'address': 'Smithfield North', 'position': {'lat': 53.349562, 'lng': -6.278198}, 'banking': False, 'bonus': False, 'bike_stands': 30, 'available_bike_stands': 16, 'available_bikes': 14, 'status': 'OPEN', 'last_update': 1677175058000}
# 2023-02-23 17:58:30,189 INFO sqlalchemy.engine.Engine SELECT DATABASE()
# 2023-02-23 17:58:30,191 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-02-23 17:58:30,430 INFO sqlalchemy.engine.Engine SELECT @@sql_mode
# 2023-02-23 17:58:30,432 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-02-23 17:58:30,527 INFO sqlalchemy.engine.Engine SELECT @@lower_case_table_names
# 2023-02-23 17:58:30,528 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-02-23 17:58:35,757 INFO sqlalchemy.engine.Engine insert into station values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2023-02-23 17:58:35,759 INFO sqlalchemy.engine.Engine [raw sql] ('Smithfield North', 0, 30, 0, 'dublin', 'SMITHFIELD NORTH', 42, 53.349562, -6.278198, 'OPEN')
# 2023-02-23 17:58:35,859 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 30, 'contract_name': 'dublin', 'name': 'PARNELL SQUARE NORTH', 'address': 'Parnell Square North', 'position': {'lat': 53.3537415547453, 'lng': -6.26530144781526}, 'banking': False, 'bonus': False, 'bike_stands': 20, 'available_bike_stands': 15, 'available_bikes': 5, 'status': 'OPEN', 'last_update': 1677174921000}
# 2023-02-23 17:58:36,106 INFO sqlalchemy.engine.Engine insert into station values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2023-02-23 17:58:36,108 INFO sqlalchemy.engine.Engine [raw sql] ('Parnell Square North', 0, 20, 0, 'dublin', 'PARNELL SQUARE NORTH', 30, 53.3537415547453, -6.26530144781526, 'OPEN')
# 2023-02-23 17:58:36,204 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 54, 'contract_name': 'dublin', 'name': 'CLONMEL STREET', 'address': 'Clonmel Street', 'position': {'lat': 53.336021, 'lng': -6.26298}, 'banking': False, 'bonus': False, 'bike_stands': 33, 'available_bike_stands': 20, 'available_bikes': 13, 'status': 'OPEN', 'last_update': 1677174819000}
# 2023-02-23 17:58:36,404 INFO sqlalchemy.engine.Engine insert into station values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2023-02-23 17:58:36,410 INFO sqlalchemy.engine.Engine [raw sql] ('Clonmel Street', 0, 33, 0, 'dublin', 'CLONMEL STREET', 54, 53.336021, -6.26298, 'OPEN')
# 2023-02-23 17:58:36,506 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 108, 'contract_name': 'dublin', 'name': 'AVONDALE ROAD', 'address': 'Avondale Road', 'position': {'lat': 53.359405, 'lng': -6.276142}, 'banking': False, 'bonus': False, 'bike_stands': 35, 'available_bike_stands': 24, 'available_bikes': 11, 'status': 'OPEN', 'last_update': 1677175099000}
# 2023-02-23 17:58:36,722 INFO sqlalchemy.engine.Engine insert into station values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2023-02-23 17:58:36,724 INFO sqlalchemy.engine.Engine [raw sql] ('Avondale Road', 0, 35, 0, 'dublin', 'AVONDALE ROAD', 108, 53.359405, -6.276142, 'OPEN')
# 2023-02-23 17:58:36,853 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 20, 'contract_name': 'dublin', 'name': 'JAMES STREET EAST', 'address': 'James Street East', 'position': {'lat': 53.336597, 'lng': -6.248109}, 'banking': False, 'bonus': False, 'bike_stands': 30, 'available_bike_stands': 19, 'available_bikes': 11, 'status': 'OPEN', 'last_update': 1677174751000}
# 2023-02-23 17:58:37,445 INFO sqlalchemy.engine.Engine insert into station values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2023-02-23 17:58:37,447 INFO sqlalchemy.engine.Engine [raw sql] ('James Street East', 0, 30, 0, 'dublin', 'JAMES STREET EAST', 20, 53.336597, -6.248109, 'OPEN')
# 2023-02-23 17:58:37,884 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 56, 'contract_name': 'dublin', 'name': 'MOUNT STREET LOWER', 'address': 'Mount Street Lower', 'position': {'lat': 53.33796, 'lng': -6.24153}, 'banking': False, 'bonus': False, 'bike_stands': 40, 'available_bike_stands': 20, 'available_bikes': 20, 'status': 'OPEN', 'last_update': 1677175031000}
# 2023-02-23 17:58:38,525 INFO sqlalchemy.engine.Engine insert into station values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2023-02-23 17:58:38,528 INFO sqlalchemy.engine.Engine [raw sql] ('Mount Street Lower', 0, 40, 0, 'dublin', 'MOUNT STREET LOWER', 56, 53.33796, -6.24153, 'OPEN')
# 2023-02-23 17:58:38,725 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 6, 'contract_name': 'dublin', 'name': 'CHRISTCHURCH PLACE', 'address': 'Christchurch Place', 'position': {'lat': 53.343368, 'lng': -6.27012}, 'banking': False, 'bonus': False, 'bike_stands': 20, 'available_bike_stands': 15, 'available_bikes': 5, 'status': 'OPEN', 'last_update': 1677175101000}
# 2023-02-23 17:58:38,961 INFO sqlalchemy.engine.Engine insert into station values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2023-02-23 17:58:38,963 INFO sqlalchemy.engine.Engine [raw sql] ('Christchurch Place', 0, 20, 0, 'dublin', 'CHRISTCHURCH PLACE', 6, 53.343368, -6.27012, 'OPEN')
# 2023-02-23 17:58:39,251 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 18, 'contract_name': 'dublin', 'name': 'GRANTHAM STREET', 'address': 'Grantham Street', 'position': {'lat': 53.334123, 'lng': -6.265436}, 'banking': False, 'bonus': False, 'bike_stands': 30, 'available_bike_stands': 23, 'available_bikes': 7, 'status': 'OPEN', 'last_update': 1677174998000}
# 2023-02-23 17:58:39,446 INFO sqlalchemy.engine.Engine insert into station values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2023-02-23 17:58:39,448 INFO sqlalchemy.engine.Engine [raw sql] ('Grantham Street', 0, 30, 0, 'dublin', 'GRANTHAM STREET', 18, 53.334123, -6.265436, 'OPEN')
# 2023-02-23 17:58:39,542 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 32, 'contract_name': 'dublin', 'name': 'PEARSE STREET', 'address': 'Pearse Street', 'position': {'lat': 53.344304, 'lng': -6.250427}, 'banking': False, 'bonus': False, 'bike_stands': 30, 'available_bike_stands': 17, 'available_bikes': 13, 'status': 'OPEN', 'last_update': 1677174996000}
# 2023-02-23 17:58:39,908 INFO sqlalchemy.engine.Engine insert into station values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2023-02-23 17:58:39,909 INFO sqlalchemy.engine.Engine [raw sql] ('Pearse Street', 0, 30, 0, 'dublin', 'PEARSE STREET', 32, 53.344304, -6.250427, 'OPEN')
# 2023-02-23 17:58:40,002 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 52, 'contract_name': 'dublin', 'name': 'YORK STREET EAST', 'address': 'York Street East', 'position': {'lat': 53.338755, 'lng': -6.262003}, 'banking': False, 'bonus': False, 'bike_stands': 32, 'available_bike_stands': 22, 'available_bikes': 10, 'status': 'OPEN', 'last_update': 1677174921000}
# 2023-02-23 17:58:40,398 INFO sqlalchemy.engine.Engine insert into station values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2023-02-23 17:58:40,399 INFO sqlalchemy.engine.Engine [raw sql] ('York Street East', 0, 32, 0, 'dublin', 'YORK STREET EAST', 52, 53.338755, -6.262003, 'OPEN')
# 2023-02-23 17:58:40,514 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 48, 'contract_name': 'dublin', 'name': 'EXCISE WALK', 'address': 'Excise Walk', 'position': {'lat': 53.347777, 'lng': -6.244239}, 'banking': False, 'bonus': False, 'bike_stands': 40, 'available_bike_stands': 28, 'available_bikes': 12, 'status': 'OPEN', 'last_update': 1677175036000}
# 2023-02-23 17:58:40,829 INFO sqlalchemy.engine.Engine insert into station values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2023-02-23 17:58:40,831 INFO sqlalchemy.engine.Engine [raw sql] ('Excise Walk', 0, 40, 0, 'dublin', 'EXCISE WALK', 48, 53.347777, -6.244239, 'OPEN')
# 2023-02-23 17:58:40,929 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 13, 'contract_name': 'dublin', 'name': 'FITZWILLIAM SQUARE WEST', 'address': 'Fitzwilliam Square West', 'position': {'lat': 53.336074, 'lng': -6.252825}, 'banking': False, 'bonus': False, 'bike_stands': 30, 'available_bike_stands': 23, 'available_bikes': 7, 'status': 'OPEN', 'last_update': 1677174861000}
# 2023-02-23 17:58:41,547 INFO sqlalchemy.engine.Engine insert into station values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2023-02-23 17:58:41,550 INFO sqlalchemy.engine.Engine [raw sql] ('Fitzwilliam Square West', 0, 30, 0, 'dublin', 'FITZWILLIAM SQUARE WEST', 13, 53.336074, -6.252825, 'OPEN')
# 2023-02-23 17:58:41,644 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 43, 'contract_name': 'dublin', 'name': 'PORTOBELLO ROAD', 'address': 'Portobello Road', 'position': {'lat': 53.330091, 'lng': -6.268044}, 'banking': False, 'bonus': False, 'bike_stands': 30, 'available_bike_stands': 17, 'available_bikes': 13, 'status': 'OPEN', 'last_update': 1677174625000}
# 2023-02-23 17:58:42,163 INFO sqlalchemy.engine.Engine insert into station values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2023-02-23 17:58:42,164 INFO sqlalchemy.engine.Engine [raw sql] ('Portobello Road', 0, 30, 0, 'dublin', 'PORTOBELLO ROAD', 43, 53.330091, -6.268044, 'OPEN')
# 2023-02-23 17:58:42,596 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 31, 'contract_name': 'dublin', 'name': 'PARNELL STREET', 'address': 'Parnell Street', 'position': {'lat': 53.350929, 'lng': -6.265125}, 'banking': False, 'bonus': False, 'bike_stands': 20, 'available_bike_stands': 12, 'available_bikes': 8, 'status': 'OPEN', 'last_update': 1677174917000}
# 2023-02-23 17:58:42,923 INFO sqlalchemy.engine.Engine insert into station values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2023-02-23 17:58:42,925 INFO sqlalchemy.engine.Engine [raw sql] ('Parnell Street', 0, 20, 0, 'dublin', 'PARNELL STREET', 31, 53.350929, -6.265125, 'OPEN')
# 2023-02-23 17:58:43,020 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 98, 'contract_name': 'dublin', 'name': 'FREDERICK STREET SOUTH', 'address': 'Frederick Street South', 'position': {'lat': 53.341515, 'lng': -6.256853}, 'banking': False, 'bonus': False, 'bike_stands': 40, 'available_bike_stands': 26, 'available_bikes': 14, 'status': 'OPEN', 'last_update': 1677174790000}
# 2023-02-23 17:58:43,213 INFO sqlalchemy.engine.Engine insert into station values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2023-02-23 17:58:43,216 INFO sqlalchemy.engine.Engine [raw sql] ('Frederick Street South', 0, 40, 0, 'dublin', 'FREDERICK STREET SOUTH', 98, 53.341515, -6.256853, 'OPEN')
# 2023-02-23 17:58:43,448 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 14, 'contract_name': 'dublin', 'name': 'FOWNES STREET UPPER', 'address': 'Fownes Street Upper', 'position': {'lat': 53.344603, 'lng': -6.263371}, 'banking': False, 'bonus': False, 'bike_stands': 30, 'available_bike_stands': 17, 'available_bikes': 13, 'status': 'OPEN', 'last_update': 1677175034000}
# 2023-02-23 17:58:43,645 INFO sqlalchemy.engine.Engine insert into station values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2023-02-23 17:58:43,647 INFO sqlalchemy.engine.Engine [raw sql] ('Fownes Street Upper', 0, 30, 0, 'dublin', 'FOWNES STREET UPPER', 14, 53.344603, -6.263371, 'OPEN')
# 2023-02-23 17:58:43,741 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 1, 'contract_name': 'dublin', 'name': 'CLARENDON ROW', 'address': 'Clarendon Row', 'position': {'lat': 53.340927, 'lng': -6.262501}, 'banking': False, 'bonus': False, 'bike_stands': 31, 'available_bike_stands': 22, 'available_bikes': 9, 'status': 'OPEN', 'last_update': 1677174676000}
# 2023-02-23 17:58:44,106 INFO sqlalchemy.engine.Engine insert into station values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2023-02-23 17:58:44,109 INFO sqlalchemy.engine.Engine [raw sql] ('Clarendon Row', 0, 31, 0, 'dublin', 'CLARENDON ROW', 1, 53.340927, -6.262501, 'OPEN')
# 2023-02-23 17:58:44,224 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 23, 'contract_name': 'dublin', 'name': 'CUSTOM HOUSE', 'address': 'Custom House', 'position': {'lat': 53.348279, 'lng': -6.254662}, 'banking': False, 'bonus': False, 'bike_stands': 30, 'available_bike_stands': 3, 'available_bikes': 27, 'status': 'OPEN', 'last_update': 1677174912000}
# 2023-02-23 17:58:44,814 INFO sqlalchemy.engine.Engine insert into station values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2023-02-23 17:58:44,816 INFO sqlalchemy.engine.Engine [raw sql] ('Custom House', 0, 30, 0, 'dublin', 'CUSTOM HOUSE', 23, 53.348279, -6.254662, 'OPEN')
# 2023-02-23 17:58:45,219 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 106, 'contract_name': 'dublin', 'name': 'RATHDOWN ROAD', 'address': 'Rathdown Road', 'position': {'lat': 53.35893, 'lng': -6.280337}, 'banking': False, 'bonus': False, 'bike_stands': 40, 'available_bike_stands': 39, 'available_bikes': 1, 'status': 'OPEN', 'last_update': 1677174594000}
# 2023-02-23 17:58:45,836 INFO sqlalchemy.engine.Engine insert into station values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2023-02-23 17:58:45,838 INFO sqlalchemy.engine.Engine [raw sql] ('Rathdown Road', 0, 40, 0, 'dublin', 'RATHDOWN ROAD', 106, 53.35893, -6.280337, 'OPEN')
# 2023-02-23 17:58:46,269 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 112, 'contract_name': 'dublin', 'name': "NORTH CIRCULAR ROAD (O'CONNELL'S)", 'address': "North Circular Road (O'Connell's)", 'position': {'lat': 53.357841, 'lng': -6.251557}, 'banking': False, 'bonus': False, 'bike_stands': 30, 'available_bike_stands': 22, 'available_bikes': 8, 'status': 'OPEN', 'last_update': 1677175109000}
# 2023-02-23 17:58:46,884 INFO sqlalchemy.engine.Engine insert into station values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2023-02-23 17:58:46,886 INFO sqlalchemy.engine.Engine [raw sql] ("North Circular Road (O'Connell's)", 0, 30, 0, 'dublin', "NORTH CIRCULAR ROAD (O'CONNELL'S)", 112, 53.357841, -6.251557, 'OPEN')
# 2023-02-23 17:58:47,315 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 68, 'contract_name': 'dublin', 'name': 'HANOVER QUAY', 'address': 'Hanover Quay', 'position': {'lat': 53.344115, 'lng': -6.237153}, 'banking': False, 'bonus': False, 'bike_stands': 40, 'available_bike_stands': 14, 'available_bikes': 26, 'status': 'OPEN', 'last_update': 1677175048000}
# 2023-02-23 17:58:47,840 INFO sqlalchemy.engine.Engine insert into station values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2023-02-23 17:58:47,842 INFO sqlalchemy.engine.Engine [raw sql] ('Hanover Quay', 0, 40, 0, 'dublin', 'HANOVER QUAY', 68, 53.344115, -6.237153, 'OPEN')
# 2023-02-23 17:58:47,937 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 74, 'contract_name': 'dublin', 'name': 'OLIVER BOND STREET', 'address': 'Oliver Bond Street', 'position': {'lat': 53.343893, 'lng': -6.280531}, 'banking': False, 'bonus': False, 'bike_stands': 30, 'available_bike_stands': 30, 'available_bikes': 0, 'status': 'OPEN', 'last_update': 1677174505000}
# 2023-02-23 17:58:48,302 INFO sqlalchemy.engine.Engine insert into station values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2023-02-23 17:58:48,303 INFO sqlalchemy.engine.Engine [raw sql] ('Oliver Bond Street', 0, 30, 0, 'dublin', 'OLIVER BOND STREET', 74, 53.343893, -6.280531, 'OPEN')
# 2023-02-23 17:58:48,404 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 87, 'contract_name': 'dublin', 'name': 'COLLINS BARRACKS MUSEUM', 'address': 'Collins Barracks Museum', 'position': {'lat': 53.347477, 'lng': -6.28525}, 'banking': False, 'bonus': False, 'bike_stands': 38, 'available_bike_stands': 19, 'available_bikes': 19, 'status': 'OPEN', 'last_update': 1677175018000}
# 2023-02-23 17:58:48,985 INFO sqlalchemy.engine.Engine insert into station values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2023-02-23 17:58:48,987 INFO sqlalchemy.engine.Engine [raw sql] ('Collins Barracks Museum', 0, 38, 0, 'dublin', 'COLLINS BARRACKS MUSEUM', 87, 53.347477, -6.28525, 'OPEN')
# 2023-02-23 17:58:49,412 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 84, 'contract_name': 'dublin', 'name': 'BROOKFIELD ROAD', 'address': 'Brookfield Road', 'position': {'lat': 53.339005, 'lng': -6.300217}, 'banking': False, 'bonus': False, 'bike_stands': 30, 'available_bike_stands': 20, 'available_bikes': 10, 'status': 'OPEN', 'last_update': 1677175034000}
# 2023-02-23 17:58:49,938 INFO sqlalchemy.engine.Engine insert into station values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2023-02-23 17:58:49,939 INFO sqlalchemy.engine.Engine [raw sql] ('Brookfield Road', 0, 30, 0, 'dublin', 'BROOKFIELD ROAD', 84, 53.339005, -6.300217, 'OPEN')
# 2023-02-23 17:58:50,034 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 90, 'contract_name': 'dublin', 'name': 'BENSON STREET', 'address': 'Benson Street', 'position': {'lat': 53.344153, 'lng': -6.233451}, 'banking': False, 'bonus': False, 'bike_stands': 40, 'available_bike_stands': 35, 'available_bikes': 5, 'status': 'OPEN', 'last_update': 1677175065000}
# 2023-02-23 17:58:50,374 INFO sqlalchemy.engine.Engine insert into station values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2023-02-23 17:58:50,376 INFO sqlalchemy.engine.Engine [raw sql] ('Benson Street', 0, 40, 0, 'dublin', 'BENSON STREET', 90, 53.344153, -6.233451, 'OPEN')
# 2023-02-23 17:58:50,472 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 11, 'contract_name': 'dublin', 'name': 'EARLSFORT TERRACE', 'address': 'Earlsfort Terrace', 'position': {'lat': 53.334295, 'lng': -6.258503}, 'banking': False, 'bonus': False, 'bike_stands': 30, 'available_bike_stands': 30, 'available_bikes': 0, 'status': 'OPEN', 'last_update': 1677175052000}
# 2023-02-23 17:58:50,883 INFO sqlalchemy.engine.Engine insert into station values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2023-02-23 17:58:50,885 INFO sqlalchemy.engine.Engine [raw sql] ('Earlsfort Terrace', 0, 30, 0, 'dublin', 'EARLSFORT TERRACE', 11, 53.334295, -6.258503, 'OPEN')
# 2023-02-23 17:58:50,983 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 17, 'contract_name': 'dublin', 'name': 'GOLDEN LANE', 'address': 'Golden Lane', 'position': {'lat': 53.340803, 'lng': -6.267732}, 'banking': False, 'bonus': False, 'bike_stands': 20, 'available_bike_stands': 17, 'available_bikes': 3, 'status': 'OPEN', 'last_update': 1677174955000}
# 2023-02-23 17:58:51,315 INFO sqlalchemy.engine.Engine insert into station values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2023-02-23 17:58:51,317 INFO sqlalchemy.engine.Engine [raw sql] ('Golden Lane', 0, 20, 0, 'dublin', 'GOLDEN LANE', 17, 53.340803, -6.267732, 'OPEN')
# 2023-02-23 17:58:51,442 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 45, 'contract_name': 'dublin', 'name': 'DEVERELL PLACE', 'address': 'Deverell Place', 'position': {'lat': 53.351464, 'lng': -6.255265}, 'banking': False, 'bonus': False, 'bike_stands': 30, 'available_bike_stands': 13, 'available_bikes': 17, 'status': 'OPEN', 'last_update': 1677174744000}
# 2023-02-23 17:58:51,841 INFO sqlalchemy.engine.Engine insert into station values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2023-02-23 17:58:51,844 INFO sqlalchemy.engine.Engine [raw sql] ('Deverell Place', 0, 30, 0, 'dublin', 'DEVERELL PLACE', 45, 53.351464, -6.255265, 'OPEN')
# 2023-02-23 17:58:51,944 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 114, 'contract_name': 'dublin', 'name': 'WILTON TERRACE (PARK)', 'address': 'Wilton Terrace (Park)', 'position': {'lat': 53.333653, 'lng': -6.248345}, 'banking': False, 'bonus': False, 'bike_stands': 40, 'available_bike_stands': 40, 'available_bikes': 0, 'status': 'OPEN', 'last_update': 1677174645000}
# 2023-02-23 17:58:52,363 INFO sqlalchemy.engine.Engine insert into station values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2023-02-23 17:58:52,367 INFO sqlalchemy.engine.Engine [raw sql] ('Wilton Terrace (Park)', 0, 40, 0, 'dublin', 'WILTON TERRACE (PARK)', 114, 53.333653, -6.248345, 'OPEN')
# 2023-02-23 17:58:52,524 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 72, 'contract_name': 'dublin', 'name': 'JOHN STREET WEST', 'address': 'John Street West', 'position': {'lat': 53.343105, 'lng': -6.277167}, 'banking': False, 'bonus': False, 'bike_stands': 31, 'available_bike_stands': 28, 'available_bikes': 3, 'status': 'OPEN', 'last_update': 1677174988000}
# 2023-02-23 17:58:53,019 INFO sqlalchemy.engine.Engine insert into station values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2023-02-23 17:58:53,021 INFO sqlalchemy.engine.Engine [raw sql] ('John Street West', 0, 31, 0, 'dublin', 'JOHN STREET WEST', 72, 53.343105, -6.277167, 'OPEN')
# 2023-02-23 17:58:53,137 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 63, 'contract_name': 'dublin', 'name': 'FENIAN STREET', 'address': 'Fenian Street', 'position': {'lat': 53.341428, 'lng': -6.24672}, 'banking': False, 'bonus': False, 'bike_stands': 35, 'available_bike_stands': 7, 'available_bikes': 28, 'status': 'OPEN', 'last_update': 1677174769000}
# 2023-02-23 17:58:53,544 INFO sqlalchemy.engine.Engine insert into station values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2023-02-23 17:58:53,546 INFO sqlalchemy.engine.Engine [raw sql] ('Fenian Street', 0, 35, 0, 'dublin', 'FENIAN STREET', 63, 53.341428, -6.24672, 'OPEN')
# 2023-02-23 17:58:54,067 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 113, 'contract_name': 'dublin', 'name': 'MERRION SQUARE SOUTH', 'address': 'Merrion Square South', 'position': {'lat': 53.338614, 'lng': -6.248606}, 'banking': False, 'bonus': False, 'bike_stands': 40, 'available_bike_stands': 34, 'available_bikes': 6, 'status': 'OPEN', 'last_update': 1677175069000}
# 2023-02-23 17:58:57,975 INFO sqlalchemy.engine.Engine insert into station values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2023-02-23 17:58:57,977 INFO sqlalchemy.engine.Engine [raw sql] ('Merrion Square South', 0, 40, 0, 'dublin', 'MERRION SQUARE SOUTH', 113, 53.338614, -6.248606, 'OPEN')
# 2023-02-23 17:58:58,136 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 91, 'contract_name': 'dublin', 'name': 'SOUTH DOCK ROAD', 'address': 'South Dock Road', 'position': {'lat': 53.341833, 'lng': -6.231291}, 'banking': False, 'bonus': False, 'bike_stands': 30, 'available_bike_stands': 6, 'available_bikes': 24, 'status': 'OPEN', 'last_update': 1677174975000}
# 2023-02-23 17:58:58,333 INFO sqlalchemy.engine.Engine insert into station values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2023-02-23 17:58:58,335 INFO sqlalchemy.engine.Engine [raw sql] ('South Dock Road', 0, 30, 0, 'dublin', 'SOUTH DOCK ROAD', 91, 53.341833, -6.231291, 'OPEN')
# 2023-02-23 17:58:58,434 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 99, 'contract_name': 'dublin', 'name': 'CITY QUAY', 'address': 'City Quay', 'position': {'lat': 53.346637, 'lng': -6.246154}, 'banking': False, 'bonus': False, 'bike_stands': 30, 'available_bike_stands': 18, 'available_bikes': 12, 'status': 'OPEN', 'last_update': 1677175058000}
# 2023-02-23 17:58:58,659 INFO sqlalchemy.engine.Engine insert into station values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2023-02-23 17:58:58,660 INFO sqlalchemy.engine.Engine [raw sql] ('City Quay', 0, 30, 0, 'dublin', 'CITY QUAY', 99, 53.346637, -6.246154, 'OPEN')
# 2023-02-23 17:58:58,755 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 9, 'contract_name': 'dublin', 'name': 'EXCHEQUER STREET', 'address': 'Exchequer Street', 'position': {'lat': 53.343034, 'lng': -6.263578}, 'banking': False, 'bonus': False, 'bike_stands': 24, 'available_bike_stands': 22, 'available_bikes': 2, 'status': 'OPEN', 'last_update': 1677174881000}
# 2023-02-23 17:58:58,947 INFO sqlalchemy.engine.Engine insert into station values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2023-02-23 17:58:58,949 INFO sqlalchemy.engine.Engine [raw sql] ('Exchequer Street', 0, 24, 0, 'dublin', 'EXCHEQUER STREET', 9, 53.343034, -6.263578, 'OPEN')
# 2023-02-23 17:58:59,047 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 67, 'contract_name': 'dublin', 'name': 'THE POINT', 'address': 'The Point', 'position': {'lat': 53.346867, 'lng': -6.230852}, 'banking': False, 'bonus': False, 'bike_stands': 40, 'available_bike_stands': 8, 'available_bikes': 32, 'status': 'OPEN', 'last_update': 1677175040000}
# 2023-02-23 17:58:59,279 INFO sqlalchemy.engine.Engine insert into station values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2023-02-23 17:58:59,281 INFO sqlalchemy.engine.Engine [raw sql] ('The Point', 0, 40, 0, 'dublin', 'THE POINT', 67, 53.346867, -6.230852, 'OPEN')
# 2023-02-23 17:58:59,424 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 116, 'contract_name': 'dublin', 'name': 'BROADSTONE', 'address': 'Broadstone', 'position': {'lat': 53.3547, 'lng': -6.272314}, 'banking': False, 'bonus': False, 'bike_stands': 30, 'available_bike_stands': 25, 'available_bikes': 5, 'status': 'OPEN', 'last_update': 1677174786000}
# 2023-02-23 17:58:59,705 INFO sqlalchemy.engine.Engine insert into station values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2023-02-23 17:58:59,707 INFO sqlalchemy.engine.Engine [raw sql] ('Broadstone', 0, 30, 0, 'dublin', 'BROADSTONE', 116, 53.3547, -6.272314, 'OPEN')
# 2023-02-23 17:58:59,804 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 55, 'contract_name': 'dublin', 'name': 'HATCH STREET', 'address': 'Hatch Street', 'position': {'lat': 53.33403, 'lng': -6.260714}, 'banking': False, 'bonus': False, 'bike_stands': 36, 'available_bike_stands': 35, 'available_bikes': 1, 'status': 'OPEN', 'last_update': 1677174952000}
# 2023-02-23 17:59:00,002 INFO sqlalchemy.engine.Engine insert into station values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2023-02-23 17:59:00,004 INFO sqlalchemy.engine.Engine [raw sql] ('Hatch Street', 0, 36, 0, 'dublin', 'HATCH STREET', 55, 53.33403, -6.260714, 'OPEN')
# 2023-02-23 17:59:00,098 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 62, 'contract_name': 'dublin', 'name': 'LIME STREET', 'address': 'Lime Street', 'position': {'lat': 53.346026, 'lng': -6.243576}, 'banking': False, 'bonus': False, 'bike_stands': 40, 'available_bike_stands': 21, 'available_bikes': 19, 'status': 'OPEN', 'last_update': 1677175027000}
# 2023-02-23 17:59:00,323 INFO sqlalchemy.engine.Engine insert into station values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2023-02-23 17:59:00,325 INFO sqlalchemy.engine.Engine [raw sql] ('Lime Street', 0, 40, 0, 'dublin', 'LIME STREET', 62, 53.346026, -6.243576, 'OPEN')
# 2023-02-23 17:59:00,419 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 5, 'contract_name': 'dublin', 'name': 'CHARLEMONT PLACE', 'address': 'Charlemont Street', 'position': {'lat': 53.330662, 'lng': -6.260177}, 'banking': False, 'bonus': False, 'bike_stands': 40, 'available_bike_stands': 20, 'available_bikes': 19, 'status': 'OPEN', 'last_update': 1677175105000}
# 2023-02-23 17:59:00,614 INFO sqlalchemy.engine.Engine insert into station values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2023-02-23 17:59:00,616 INFO sqlalchemy.engine.Engine [raw sql] ('Charlemont Street', 0, 40, 0, 'dublin', 'CHARLEMONT PLACE', 5, 53.330662, -6.260177, 'OPEN')
# 2023-02-23 17:59:00,756 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 97, 'contract_name': 'dublin', 'name': 'KILMAINHAM GAOL', 'address': 'Kilmainham Gaol', 'position': {'lat': 53.342113, 'lng': -6.310015}, 'banking': False, 'bonus': False, 'bike_stands': 40, 'available_bike_stands': 32, 'available_bikes': 8, 'status': 'OPEN', 'last_update': 1677175052000}
# 2023-02-23 17:59:00,957 INFO sqlalchemy.engine.Engine insert into station values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2023-02-23 17:59:00,960 INFO sqlalchemy.engine.Engine [raw sql] ('Kilmainham Gaol', 0, 40, 0, 'dublin', 'KILMAINHAM GAOL', 97, 53.342113, -6.310015, 'OPEN')
# 2023-02-23 17:59:01,056 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 61, 'contract_name': 'dublin', 'name': 'HARDWICKE PLACE', 'address': 'Hardwicke Place', 'position': {'lat': 53.357043, 'lng': -6.263232}, 'banking': False, 'bonus': False, 'bike_stands': 25, 'available_bike_stands': 17, 'available_bikes': 8, 'status': 'OPEN', 'last_update': 1677175068000}
# 2023-02-23 17:59:01,570 INFO sqlalchemy.engine.Engine insert into station values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2023-02-23 17:59:01,573 INFO sqlalchemy.engine.Engine [raw sql] ('Hardwicke Place', 0, 25, 0, 'dublin', 'HARDWICKE PLACE', 61, 53.357043, -6.263232, 'OPEN')
# 2023-02-23 17:59:01,998 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 77, 'contract_name': 'dublin', 'name': 'WOLFE TONE STREET', 'address': 'Wolfe Tone Street', 'position': {'lat': 53.348875, 'lng': -6.267459}, 'banking': False, 'bonus': False, 'bike_stands': 29, 'available_bike_stands': 28, 'available_bikes': 1, 'status': 'OPEN', 'last_update': 1677174747000}
# 2023-02-23 17:59:02,526 INFO sqlalchemy.engine.Engine insert into station values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2023-02-23 17:59:02,528 INFO sqlalchemy.engine.Engine [raw sql] ('Wolfe Tone Street', 0, 29, 0, 'dublin', 'WOLFE TONE STREET', 77, 53.348875, -6.267459, 'OPEN')
# 2023-02-23 17:59:02,624 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 4, 'contract_name': 'dublin', 'name': 'GREEK STREET', 'address': 'Greek Street', 'position': {'lat': 53.346874, 'lng': -6.272976}, 'banking': False, 'bonus': False, 'bike_stands': 20, 'available_bike_stands': 15, 'available_bikes': 5, 'status': 'OPEN', 'last_update': 1677174863000}
# 2023-02-23 17:59:02,944 INFO sqlalchemy.engine.Engine insert into station values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2023-02-23 17:59:02,946 INFO sqlalchemy.engine.Engine [raw sql] ('Greek Street', 0, 20, 0, 'dublin', 'GREEK STREET', 4, 53.346874, -6.272976, 'OPEN')
# 2023-02-23 17:59:03,043 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 49, 'contract_name': 'dublin', 'name': 'GUILD STREET', 'address': 'Guild Street', 'position': {'lat': 53.347932, 'lng': -6.240928}, 'banking': False, 'bonus': False, 'bike_stands': 40, 'available_bike_stands': 0, 'available_bikes': 40, 'status': 'OPEN', 'last_update': 1677174822000}
# 2023-02-23 17:59:03,376 INFO sqlalchemy.engine.Engine insert into station values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2023-02-23 17:59:03,378 INFO sqlalchemy.engine.Engine [raw sql] ('Guild Street', 0, 40, 0, 'dublin', 'GUILD STREET', 49, 53.347932, -6.240928, 'OPEN')
# 2023-02-23 17:59:03,474 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 19, 'contract_name': 'dublin', 'name': 'HERBERT PLACE', 'address': 'Herbert Place', 'position': {'lat': 53.334432, 'lng': -6.245575}, 'banking': False, 'bonus': False, 'bike_stands': 30, 'available_bike_stands': 29, 'available_bikes': 1, 'status': 'OPEN', 'last_update': 1677175077000}
# 2023-02-23 17:59:03,672 INFO sqlalchemy.engine.Engine insert into station values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2023-02-23 17:59:03,674 INFO sqlalchemy.engine.Engine [raw sql] ('Herbert Place', 0, 30, 0, 'dublin', 'HERBERT PLACE', 19, 53.334432, -6.245575, 'OPEN')
# 2023-02-23 17:59:03,931 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 7, 'contract_name': 'dublin', 'name': 'HIGH STREET', 'address': 'High Street', 'position': {'lat': 53.343565, 'lng': -6.275071}, 'banking': False, 'bonus': False, 'bike_stands': 29, 'available_bike_stands': 28, 'available_bikes': 1, 'status': 'OPEN', 'last_update': 1677175059000}
# 2023-02-23 17:59:04,126 INFO sqlalchemy.engine.Engine insert into station values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2023-02-23 17:59:04,128 INFO sqlalchemy.engine.Engine [raw sql] ('High Street', 0, 29, 0, 'dublin', 'HIGH STREET', 7, 53.343565, -6.275071, 'OPEN')
# 2023-02-23 17:59:04,426 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 60, 'contract_name': 'dublin', 'name': 'NORTH CIRCULAR ROAD', 'address': 'North Circular Road', 'position': {'lat': 53.359624, 'lng': -6.260348}, 'banking': False, 'bonus': False, 'bike_stands': 30, 'available_bike_stands': 10, 'available_bikes': 20, 'status': 'OPEN', 'last_update': 1677174592000}
# 2023-02-23 17:59:04,634 INFO sqlalchemy.engine.Engine insert into station values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2023-02-23 17:59:04,635 INFO sqlalchemy.engine.Engine [raw sql] ('North Circular Road', 0, 30, 0, 'dublin', 'NORTH CIRCULAR ROAD', 60, 53.359624, -6.260348, 'OPEN')
# 2023-02-23 17:59:04,736 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 102, 'contract_name': 'dublin', 'name': 'WESTERN WAY', 'address': 'Western Way', 'position': {'lat': 53.354929, 'lng': -6.269425}, 'banking': False, 'bonus': False, 'bike_stands': 40, 'available_bike_stands': 27, 'available_bikes': 13, 'status': 'OPEN', 'last_update': 1677175056000}
# 2023-02-23 17:59:05,051 INFO sqlalchemy.engine.Engine insert into station values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2023-02-23 17:59:05,053 INFO sqlalchemy.engine.Engine [raw sql] ('Western Way', 0, 40, 0, 'dublin', 'WESTERN WAY', 102, 53.354929, -6.269425, 'OPEN')
# 2023-02-23 17:59:05,157 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 38, 'contract_name': 'dublin', 'name': 'TALBOT STREET', 'address': 'Talbot Street', 'position': {'lat': 53.350974, 'lng': -6.25294}, 'banking': False, 'bonus': False, 'bike_stands': 40, 'available_bike_stands': 11, 'available_bikes': 28, 'status': 'OPEN', 'last_update': 1677174892000}
# 2023-02-23 17:59:05,566 INFO sqlalchemy.engine.Engine insert into station values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2023-02-23 17:59:05,569 INFO sqlalchemy.engine.Engine [raw sql] ('Talbot Street', 0, 40, 0, 'dublin', 'TALBOT STREET', 38, 53.350974, -6.25294, 'OPEN')
# 2023-02-23 17:59:05,663 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 53, 'contract_name': 'dublin', 'name': 'NEWMAN HOUSE', 'address': 'Newman House', 'position': {'lat': 53.337132, 'lng': -6.26059}, 'banking': False, 'bonus': False, 'bike_stands': 40, 'available_bike_stands': 39, 'available_bikes': 1, 'status': 'OPEN', 'last_update': 1677174995000}
# 2023-02-23 17:59:05,998 INFO sqlalchemy.engine.Engine insert into station values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2023-02-23 17:59:06,000 INFO sqlalchemy.engine.Engine [raw sql] ('Newman House', 0, 40, 0, 'dublin', 'NEWMAN HOUSE', 53, 53.337132, -6.26059, 'OPEN')
# 2023-02-23 17:59:06,099 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 58, 'contract_name': 'dublin', 'name': "SIR PATRICK DUN'S", 'address': "Sir Patrick's Dun", 'position': {'lat': 53.339218, 'lng': -6.240642}, 'banking': False, 'bonus': False, 'bike_stands': 40, 'available_bike_stands': 16, 'available_bikes': 24, 'status': 'OPEN', 'last_update': 1677174972000}
# 2023-02-23 17:59:06,522 INFO sqlalchemy.engine.Engine insert into station values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2023-02-23 17:59:06,524 INFO sqlalchemy.engine.Engine [raw sql] ("Sir Patrick's Dun", 0, 40, 0, 'dublin', "SIR PATRICK DUN'S", 58, 53.339218, -6.240642, 'OPEN')
# 2023-02-23 17:59:06,621 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 66, 'contract_name': 'dublin', 'name': 'NEW CENTRAL BANK', 'address': 'New Central Bank', 'position': {'lat': 53.347122, 'lng': -6.234749}, 'banking': False, 'bonus': False, 'bike_stands': 40, 'available_bike_stands': 39, 'available_bikes': 1, 'status': 'OPEN', 'last_update': 1677175107000}
# 2023-02-23 17:59:06,815 INFO sqlalchemy.engine.Engine insert into station values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2023-02-23 17:59:06,818 INFO sqlalchemy.engine.Engine [raw sql] ('New Central Bank', 0, 40, 0, 'dublin', 'NEW CENTRAL BANK', 66, 53.347122, -6.234749, 'OPEN')
# 2023-02-23 17:59:07,089 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 104, 'contract_name': 'dublin', 'name': 'GRANGEGORMAN LOWER (CENTRAL)', 'address': 'Grangegorman Lower (Central)', 'position': {'lat': 53.355173, 'lng': -6.278424}, 'banking': False, 'bonus': False, 'bike_stands': 40, 'available_bike_stands': 32, 'available_bikes': 8, 'status': 'OPEN', 'last_update': 1677174948000}
# 2023-02-23 17:59:07,308 INFO sqlalchemy.engine.Engine insert into station values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2023-02-23 17:59:07,309 INFO sqlalchemy.engine.Engine [raw sql] ('Grangegorman Lower (Central)', 0, 40, 0, 'dublin', 'GRANGEGORMAN LOWER (CENTRAL)', 104, 53.355173, -6.278424, 'OPEN')
# 2023-02-23 17:59:07,570 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 101, 'contract_name': 'dublin', 'name': 'KING STREET NORTH', 'address': 'King Street North', 'position': {'lat': 53.350291, 'lng': -6.273507}, 'banking': False, 'bonus': False, 'bike_stands': 30, 'available_bike_stands': 12, 'available_bikes': 18, 'status': 'OPEN', 'last_update': 1677175078000}
# 2023-02-23 17:59:07,766 INFO sqlalchemy.engine.Engine insert into station values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2023-02-23 17:59:07,766 INFO sqlalchemy.engine.Engine [raw sql] ('King Street North', 0, 30, 0, 'dublin', 'KING STREET NORTH', 101, 53.350291, -6.273507, 'OPEN')
# 2023-02-23 17:59:07,860 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 115, 'contract_name': 'dublin', 'name': 'KILLARNEY STREET', 'address': 'Killarney Street', 'position': {'lat': 53.354845, 'lng': -6.247579}, 'banking': False, 'bonus': False, 'bike_stands': 30, 'available_bike_stands': 27, 'available_bikes': 3, 'status': 'OPEN', 'last_update': 1677175087000}
# 2023-02-23 17:59:08,187 INFO sqlalchemy.engine.Engine insert into station values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2023-02-23 17:59:08,188 INFO sqlalchemy.engine.Engine [raw sql] ('Killarney Street', 0, 30, 0, 'dublin', 'KILLARNEY STREET', 115, 53.354845, -6.247579, 'OPEN')
# 2023-02-23 17:59:08,336 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 47, 'contract_name': 'dublin', 'name': 'HERBERT STREET', 'address': 'Herbert Street', 'position': {'lat': 53.335742, 'lng': -6.24551}, 'banking': False, 'bonus': False, 'bike_stands': 40, 'available_bike_stands': 28, 'available_bikes': 12, 'status': 'OPEN', 'last_update': 1677174945000}
# 2023-02-23 17:59:08,713 INFO sqlalchemy.engine.Engine insert into station values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2023-02-23 17:59:08,714 INFO sqlalchemy.engine.Engine [raw sql] ('Herbert Street', 0, 40, 0, 'dublin', 'HERBERT STREET', 47, 53.335742, -6.24551, 'OPEN')
# 2023-02-23 17:59:08,832 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 117, 'contract_name': 'dublin', 'name': 'HANOVER QUAY EAST', 'address': 'Hanover Quay East', 'position': {'lat': 53.343653, 'lng': -6.231755}, 'banking': False, 'bonus': False, 'bike_stands': 40, 'available_bike_stands': 35, 'available_bikes': 5, 'status': 'OPEN', 'last_update': 1677175060000}
# 2023-02-23 17:59:09,143 INFO sqlalchemy.engine.Engine insert into station values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2023-02-23 17:59:09,144 INFO sqlalchemy.engine.Engine [raw sql] ('Hanover Quay East', 0, 40, 0, 'dublin', 'HANOVER QUAY EAST', 117, 53.343653, -6.231755, 'OPEN')
# 2023-02-23 17:59:09,241 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 8, 'contract_name': 'dublin', 'name': 'CUSTOM HOUSE QUAY', 'address': 'Custom House Quay', 'position': {'lat': 53.347884, 'lng': -6.248048}, 'banking': False, 'bonus': False, 'bike_stands': 30, 'available_bike_stands': 10, 'available_bikes': 20, 'status': 'OPEN', 'last_update': 1677175101000}
# 2023-02-23 17:59:09,669 INFO sqlalchemy.engine.Engine insert into station values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2023-02-23 17:59:09,672 INFO sqlalchemy.engine.Engine [raw sql] ('Custom House Quay', 0, 30, 0, 'dublin', 'CUSTOM HOUSE QUAY', 8, 53.347884, -6.248048, 'OPEN')
# 2023-02-23 17:59:09,787 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 27, 'contract_name': 'dublin', 'name': 'MOLESWORTH STREET', 'address': 'Molesworth Street', 'position': {'lat': 53.341288, 'lng': -6.258117}, 'banking': False, 'bonus': False, 'bike_stands': 20, 'available_bike_stands': 11, 'available_bikes': 9, 'status': 'OPEN', 'last_update': 1677174567000}
# 2023-02-23 17:59:09,983 INFO sqlalchemy.engine.Engine insert into station values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2023-02-23 17:59:09,985 INFO sqlalchemy.engine.Engine [raw sql] ('Molesworth Street', 0, 20, 0, 'dublin', 'MOLESWORTH STREET', 27, 53.341288, -6.258117, 'OPEN')
# 2023-02-23 17:59:10,191 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 16, 'contract_name': 'dublin', 'name': 'GEORGES QUAY', 'address': 'Georges Quay', 'position': {'lat': 53.347508, 'lng': -6.252192}, 'banking': False, 'bonus': False, 'bike_stands': 20, 'available_bike_stands': 7, 'available_bikes': 13, 'status': 'OPEN', 'last_update': 1677174874000}
# 2023-02-23 17:59:10,479 INFO sqlalchemy.engine.Engine insert into station values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2023-02-23 17:59:10,481 INFO sqlalchemy.engine.Engine [raw sql] ('Georges Quay', 0, 20, 0, 'dublin', 'GEORGES QUAY', 16, 53.347508, -6.252192, 'OPEN')
# 2023-02-23 17:59:10,717 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 96, 'contract_name': 'dublin', 'name': 'KILMAINHAM LANE', 'address': 'Kilmainham Lane', 'position': {'lat': 53.341805, 'lng': -6.305085}, 'banking': False, 'bonus': False, 'bike_stands': 30, 'available_bike_stands': 21, 'available_bikes': 9, 'status': 'OPEN', 'last_update': 1677175084000}
# 2023-02-23 17:59:10,952 INFO sqlalchemy.engine.Engine insert into station values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2023-02-23 17:59:10,953 INFO sqlalchemy.engine.Engine [raw sql] ('Kilmainham Lane', 0, 30, 0, 'dublin', 'KILMAINHAM LANE', 96, 53.341805, -6.305085, 'OPEN')
# 2023-02-23 17:59:11,242 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 82, 'contract_name': 'dublin', 'name': 'MOUNT BROWN', 'address': 'Mount Brown', 'position': {'lat': 53.341645, 'lng': -6.29719}, 'banking': False, 'bonus': False, 'bike_stands': 22, 'available_bike_stands': 15, 'available_bikes': 7, 'status': 'OPEN', 'last_update': 1677174878000}
# 2023-02-23 17:59:11,497 INFO sqlalchemy.engine.Engine insert into station values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2023-02-23 17:59:11,499 INFO sqlalchemy.engine.Engine [raw sql] ('Mount Brown', 0, 22, 0, 'dublin', 'MOUNT BROWN', 82, 53.341645, -6.29719, 'OPEN')
# 2023-02-23 17:59:11,763 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 76, 'contract_name': 'dublin', 'name': 'MARKET STREET SOUTH', 'address': 'Market Street South', 'position': {'lat': 53.342296, 'lng': -6.287661}, 'banking': False, 'bonus': False, 'bike_stands': 38, 'available_bike_stands': 25, 'available_bikes': 13, 'status': 'OPEN', 'last_update': 1677174714000}
# 2023-02-23 17:59:11,957 INFO sqlalchemy.engine.Engine insert into station values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2023-02-23 17:59:11,959 INFO sqlalchemy.engine.Engine [raw sql] ('Market Street South', 0, 38, 0, 'dublin', 'MARKET STREET SOUTH', 76, 53.342296, -6.287661, 'OPEN')
# 2023-02-23 17:59:12,053 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 71, 'contract_name': 'dublin', 'name': 'KEVIN STREET', 'address': 'Kevin Street', 'position': {'lat': 53.337757, 'lng': -6.267699}, 'banking': False, 'bonus': False, 'bike_stands': 40, 'available_bike_stands': 34, 'available_bikes': 6, 'status': 'OPEN', 'last_update': 1677175083000}
# 2023-02-23 17:59:12,382 INFO sqlalchemy.engine.Engine insert into station values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2023-02-23 17:59:12,383 INFO sqlalchemy.engine.Engine [raw sql] ('Kevin Street', 0, 40, 0, 'dublin', 'KEVIN STREET', 71, 53.337757, -6.267699, 'OPEN')
# 2023-02-23 17:59:12,478 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 79, 'contract_name': 'dublin', 'name': 'ECCLES STREET EAST', 'address': 'Eccles Street East', 'position': {'lat': 53.358115, 'lng': -6.265601}, 'banking': False, 'bonus': False, 'bike_stands': 27, 'available_bike_stands': 19, 'available_bikes': 8, 'status': 'OPEN', 'last_update': 1677174989000}
# 2023-02-23 17:59:12,813 INFO sqlalchemy.engine.Engine insert into station values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2023-02-23 17:59:12,815 INFO sqlalchemy.engine.Engine [raw sql] ('Eccles Street East', 0, 27, 0, 'dublin', 'ECCLES STREET EAST', 79, 53.358115, -6.265601, 'OPEN')
# 2023-02-23 17:59:12,911 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 69, 'contract_name': 'dublin', 'name': 'GRAND CANAL DOCK', 'address': 'Grand Canal Dock', 'position': {'lat': 53.342638, 'lng': -6.238695}, 'banking': False, 'bonus': False, 'bike_stands': 40, 'available_bike_stands': 20, 'available_bikes': 20, 'status': 'OPEN', 'last_update': 1677175085000}
# 2023-02-23 17:59:13,134 INFO sqlalchemy.engine.Engine insert into station values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2023-02-23 17:59:13,136 INFO sqlalchemy.engine.Engine [raw sql] ('Grand Canal Dock', 0, 40, 0, 'dublin', 'GRAND CANAL DOCK', 69, 53.342638, -6.238695, 'OPEN')
# 2023-02-23 17:59:13,339 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 25, 'contract_name': 'dublin', 'name': 'MERRION SQUARE EAST', 'address': 'Merrion Square East', 'position': {'lat': 53.339434, 'lng': -6.246548}, 'banking': False, 'bonus': False, 'bike_stands': 30, 'available_bike_stands': 30, 'available_bikes': 0, 'status': 'OPEN', 'last_update': 1677174778000}
# 2023-02-23 17:59:13,544 INFO sqlalchemy.engine.Engine insert into station values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2023-02-23 17:59:13,545 INFO sqlalchemy.engine.Engine [raw sql] ('Merrion Square East', 0, 30, 0, 'dublin', 'MERRION SQUARE EAST', 25, 53.339434, -6.246548, 'OPEN')
# 2023-02-23 17:59:13,862 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 51, 'contract_name': 'dublin', 'name': 'YORK STREET WEST', 'address': 'York Street West', 'position': {'lat': 53.339334, 'lng': -6.264699}, 'banking': False, 'bonus': False, 'bike_stands': 40, 'available_bike_stands': 23, 'available_bikes': 16, 'status': 'OPEN', 'last_update': 1677174687000}
# 2023-02-23 17:59:14,059 INFO sqlalchemy.engine.Engine insert into station values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2023-02-23 17:59:14,061 INFO sqlalchemy.engine.Engine [raw sql] ('York Street West', 0, 40, 0, 'dublin', 'YORK STREET WEST', 51, 53.339334, -6.264699, 'OPEN')
# 2023-02-23 17:59:14,162 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 37, 'contract_name': 'dublin', 'name': "ST. STEPHEN'S GREEN SOUTH", 'address': "St. Stephen's Green South", 'position': {'lat': 53.337494, 'lng': -6.26199}, 'banking': True, 'bonus': False, 'bike_stands': 30, 'available_bike_stands': 20, 'available_bikes': 10, 'status': 'OPEN', 'last_update': 1677174912000}
# 2023-02-23 17:59:14,480 INFO sqlalchemy.engine.Engine insert into station values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2023-02-23 17:59:14,483 INFO sqlalchemy.engine.Engine [raw sql] ("St. Stephen's Green South", 1, 30, 0, 'dublin', "ST. STEPHEN'S GREEN SOUTH", 37, 53.337494, -6.26199, 'OPEN')
# 2023-02-23 17:59:14,578 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 59, 'contract_name': 'dublin', 'name': 'DENMARK STREET GREAT', 'address': 'Denmark Street Great', 'position': {'lat': 53.35561, 'lng': -6.261397}, 'banking': False, 'bonus': False, 'bike_stands': 20, 'available_bike_stands': 19, 'available_bikes': 1, 'status': 'OPEN', 'last_update': 1677175016000}
# 2023-02-23 17:59:14,915 INFO sqlalchemy.engine.Engine insert into station values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2023-02-23 17:59:14,918 INFO sqlalchemy.engine.Engine [raw sql] ('Denmark Street Great', 0, 20, 0, 'dublin', 'DENMARK STREET GREAT', 59, 53.35561, -6.261397, 'OPEN')
# 2023-02-23 17:59:15,017 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 95, 'contract_name': 'dublin', 'name': 'ROYAL HOSPITAL', 'address': 'Royal Hospital', 'position': {'lat': 53.343897, 'lng': -6.29706}, 'banking': False, 'bonus': False, 'bike_stands': 40, 'available_bike_stands': 33, 'available_bikes': 7, 'status': 'OPEN', 'last_update': 1677174940000}
# 2023-02-23 17:59:15,220 INFO sqlalchemy.engine.Engine insert into station values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2023-02-23 17:59:15,222 INFO sqlalchemy.engine.Engine [raw sql] ('Royal Hospital', 0, 40, 0, 'dublin', 'ROYAL HOSPITAL', 95, 53.343897, -6.29706, 'OPEN')
# 2023-02-23 17:59:15,434 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 94, 'contract_name': 'dublin', 'name': 'HEUSTON STATION (CAR PARK)', 'address': 'Heuston Station (Car Park)', 'position': {'lat': 53.346985, 'lng': -6.297804}, 'banking': False, 'bonus': False, 'bike_stands': 40, 'available_bike_stands': 38, 'available_bikes': 2, 'status': 'OPEN', 'last_update': 1677174825000}
# 2023-02-23 17:59:15,630 INFO sqlalchemy.engine.Engine insert into station values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2023-02-23 17:59:15,633 INFO sqlalchemy.engine.Engine [raw sql] ('Heuston Station (Car Park)', 0, 40, 0, 'dublin', 'HEUSTON STATION (CAR PARK)', 94, 53.346985, -6.297804, 'OPEN')
# 2023-02-23 17:59:16,093 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 105, 'contract_name': 'dublin', 'name': 'GRANGEGORMAN LOWER (NORTH)', 'address': 'Grangegorman Lower (North)', 'position': {'lat': 53.355954, 'lng': -6.278378}, 'banking': False, 'bonus': False, 'bike_stands': 36, 'available_bike_stands': 20, 'available_bikes': 16, 'status': 'OPEN', 'last_update': 1677175090000}
# 2023-02-23 17:59:17,140 INFO sqlalchemy.engine.Engine insert into station values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2023-02-23 17:59:17,141 INFO sqlalchemy.engine.Engine [raw sql] ('Grangegorman Lower (North)', 0, 36, 0, 'dublin', 'GRANGEGORMAN LOWER (NORTH)', 105, 53.355954, -6.278378, 'OPEN')
# 2023-02-23 17:59:17,270 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 36, 'contract_name': 'dublin', 'name': "ST. STEPHEN'S GREEN EAST", 'address': "St. Stephen's Green East", 'position': {'lat': 53.337824, 'lng': -6.256035}, 'banking': False, 'bonus': False, 'bike_stands': 40, 'available_bike_stands': 33, 'available_bikes': 7, 'status': 'OPEN', 'last_update': 1677174841000}
# 2023-02-23 17:59:17,535 INFO sqlalchemy.engine.Engine insert into station values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
# ...
# 2023-02-23 17:59:25,923 INFO sqlalchemy.engine.Engine insert into station values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2023-02-23 17:59:25,924 INFO sqlalchemy.engine.Engine [raw sql] ('Parkgate Street', 0, 38, 0, 'dublin', 'PARKGATE STREET', 86, 53.347972, -6.291804, 'OPEN')
# 2023-02-23 17:59:26,018 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 35, 'contract_name': 'dublin', 'name': 'SMITHFIELD', 'address': 'Smithfield', 'position': {'lat': 53.347692, 'lng': -6.278214}, 'banking': False, 'bonus': False, 'bike_stands': 30, 'available_bike_stands': 25, 'available_bikes': 4, 'status': 'OPEN', 'last_update': 1677174808000}
# 2023-02-23 17:59:26,447 INFO sqlalchemy.engine.Engine insert into station values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2023-02-23 17:59:26,447 INFO sqlalchemy.engine.Engine [raw sql] ('Smithfield', 0, 30, 0, 'dublin', 'SMITHFIELD', 35, 53.347692, -6.278214, 'OPEN')
# 2023-02-23 17:59:26,557 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 10, 'contract_name': 'dublin', 'name': 'DAME STREET', 'address': 'Dame Street', 'position': {'lat': 53.344007, 'lng': -6.266802}, 'banking': True, 'bonus': False, 'bike_stands': 16, 'available_bike_stands': 13, 'available_bikes': 3, 'status': 'OPEN', 'last_update': 1677174830000}
# 2023-02-23 17:59:26,785 INFO sqlalchemy.engine.Engine insert into station values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2023-02-23 17:59:26,786 INFO sqlalchemy.engine.Engine [raw sql] ('Dame Street', 1, 16, 0, 'dublin', 'DAME STREET', 10, 53.344007, -6.266802, 'OPEN')
# 2023-02-23 17:59:26,970 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 100, 'contract_name': 'dublin', 'name': 'HEUSTON BRIDGE (SOUTH)', 'address': 'Heuston Bridge (South)', 'position': {'lat': 53.347106, 'lng': -6.292041}, 'banking': False, 'bonus': False, 'bike_stands': 25, 'available_bike_stands': 0, 'available_bikes': 25, 'status': 'OPEN', 'last_update': 1677175082000}
# 2023-02-23 17:59:27,163 INFO sqlalchemy.engine.Engine insert into station values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2023-02-23 17:59:27,166 INFO sqlalchemy.engine.Engine [raw sql] ('Heuston Bridge (South)', 0, 25, 0, 'dublin', 'HEUSTON BRIDGE (SOUTH)', 100, 53.347106, -6.292041, 'OPEN')
# 2023-02-23 17:59:27,265 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 24, 'contract_name': 'dublin', 'name': 'CATHAL BRUGHA STREET', 'address': 'Cathal Brugha Street', 'position': {'lat': 53.352149, 'lng': -6.260533}, 'banking': False, 'bonus': False, 'bike_stands': 20, 'available_bike_stands': 5, 'available_bikes': 15, 'status': 'OPEN', 'last_update': 1677175015000}
# 2023-02-23 17:59:27,587 INFO sqlalchemy.engine.Engine insert into station values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2023-02-23 17:59:27,588 INFO sqlalchemy.engine.Engine [raw sql] ('Cathal Brugha Street', 0, 20, 0, 'dublin', 'CATHAL BRUGHA STREET', 24, 53.352149, -6.260533, 'OPEN')
# 2023-02-23 17:59:27,685 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 64, 'contract_name': 'dublin', 'name': 'SANDWITH STREET', 'address': 'Sandwith Street', 'position': {'lat': 53.345203, 'lng': -6.247163}, 'banking': False, 'bonus': False, 'bike_stands': 40, 'available_bike_stands': 27, 'available_bikes': 13, 'status': 'OPEN', 'last_update': 1677174809000}
# 2023-02-23 17:59:28,020 INFO sqlalchemy.engine.Engine insert into station values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2023-02-23 17:59:28,022 INFO sqlalchemy.engine.Engine [raw sql] ('Sandwith Street', 0, 40, 0, 'dublin', 'SANDWITH STREET', 64, 53.345203, -6.247163, 'OPEN')
# 2023-02-23 17:59:28,116 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 109, 'contract_name': 'dublin', 'name': 'BUCKINGHAM STREET LOWER', 'address': 'Buckingham Street Lower', 'position': {'lat': 53.353331, 'lng': -6.249319}, 'banking': False, 'bonus': False, 'bike_stands': 29, 'available_bike_stands': 7, 'available_bikes': 22, 'status': 'OPEN', 'last_update': 1677174683000}
# 2023-02-23 17:59:28,310 INFO sqlalchemy.engine.Engine insert into station values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2023-02-23 17:59:28,313 INFO sqlalchemy.engine.Engine [raw sql] ('Buckingham Street Lower', 0, 29, 0, 'dublin', 'BUCKINGHAM STREET LOWER', 109, 53.353331, -6.249319, 'OPEN')
# 2023-02-23 17:59:28,544 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 85, 'contract_name': 'dublin', 'name': 'ROTHE ABBEY', 'address': 'Rothe Abbey', 'position': {'lat': 53.338776, 'lng': -6.30395}, 'banking': False, 'bonus': False, 'bike_stands': 35, 'available_bike_stands': 33, 'available_bikes': 2, 'status': 'OPEN', 'last_update': 1677174924000}
# 2023-02-23 17:59:28,737 INFO sqlalchemy.engine.Engine insert into station values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2023-02-23 17:59:28,738 INFO sqlalchemy.engine.Engine [raw sql] ('Rothe Abbey', 0, 35, 0, 'dublin', 'ROTHE ABBEY', 85, 53.338776, -6.30395, 'OPEN')
# 2023-02-23 17:59:28,831 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 107, 'contract_name': 'dublin', 'name': 'CHARLEVILLE ROAD', 'address': 'Charleville Road', 'position': {'lat': 53.359157, 'lng': -6.281866}, 'banking': False, 'bonus': False, 'bike_stands': 40, 'available_bike_stands': 32, 'available_bikes': 8, 'status': 'OPEN', 'last_update': 1677174962000}
# 2023-02-23 17:59:29,163 INFO sqlalchemy.engine.Engine insert into station values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2023-02-23 17:59:29,165 INFO sqlalchemy.engine.Engine [raw sql] ('Charleville Road', 0, 40, 0, 'dublin', 'CHARLEVILLE ROAD', 107, 53.359157, -6.281866, 'OPEN')
# 2023-02-23 17:59:29,280 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 33, 'contract_name': 'dublin', 'name': "PRINCES STREET / O'CONNELL STREET", 'address': "Princes Street / O'Connell Street", 'position': {'lat': 53.349013, 'lng': -6.260311}, 'banking': True, 'bonus': False, 'bike_stands': 23, 'available_bike_stands': 5, 'available_bikes': 18, 'status': 'OPEN', 'last_update': 1677174935000}
# 2023-02-23 17:59:29,686 INFO sqlalchemy.engine.Engine insert into station values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2023-02-23 17:59:29,687 INFO sqlalchemy.engine.Engine [raw sql] ("Princes Street / O'Connell Street", 1, 23, 0, 'dublin', "PRINCES STREET / O'CONNELL STREET", 33, 53.349013, -6.260311, 'OPEN')
# 2023-02-23 17:59:29,781 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 44, 'contract_name': 'dublin', 'name': 'UPPER SHERRARD STREET', 'address': 'Upper Sherrard Street', 'position': {'lat': 53.358437, 'lng': -6.260641}, 'banking': False, 'bonus': False, 'bike_stands': 30, 'available_bike_stands': 20, 'available_bikes': 10, 'status': 'OPEN', 'last_update': 1677174876000}
# 2023-02-23 17:59:30,119 INFO sqlalchemy.engine.Engine insert into station values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2023-02-23 17:59:30,121 INFO sqlalchemy.engine.Engine [raw sql] ('Upper Sherrard Street', 0, 30, 0, 'dublin', 'UPPER SHERRARD STREET', 44, 53.358437, -6.260641, 'OPEN')
# 2023-02-23 17:59:30,224 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 89, 'contract_name': 'dublin', 'name': 'FITZWILLIAM SQUARE EAST', 'address': 'Fitzwilliam Square East', 'position': {'lat': 53.335211, 'lng': -6.2509}, 'banking': False, 'bonus': False, 'bike_stands': 40, 'available_bike_stands': 36, 'available_bikes': 3, 'status': 'OPEN', 'last_update': 1677174875000}
# 2023-02-23 17:59:30,643 INFO sqlalchemy.engine.Engine insert into station values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2023-02-23 17:59:30,645 INFO sqlalchemy.engine.Engine [raw sql] ('Fitzwilliam Square East', 0, 40, 0, 'dublin', 'FITZWILLIAM SQUARE EAST', 89, 53.335211, -6.2509, 'OPEN')
# 2023-02-23 17:59:30,740 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 57, 'contract_name': 'dublin', 'name': 'GRATTAN STREET', 'address': 'Grattan Street', 'position': {'lat': 53.339629, 'lng': -6.243778}, 'banking': False, 'bonus': False, 'bike_stands': 23, 'available_bike_stands': 12, 'available_bikes': 11, 'status': 'OPEN', 'last_update': 1677175066000}
# 2023-02-23 17:59:30,967 INFO sqlalchemy.engine.Engine insert into station values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2023-02-23 17:59:30,969 INFO sqlalchemy.engine.Engine [raw sql] ('Grattan Street', 0, 23, 0, 'dublin', 'GRATTAN STREET', 57, 53.339629, -6.243778, 'OPEN')
# 2023-02-23 17:59:31,166 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 80, 'contract_name': 'dublin', 'name': 'ST JAMES HOSPITAL (LUAS)', 'address': 'St James Hospital (Luas)', 'position': {'lat': 53.341359, 'lng': -6.292951}, 'banking': False, 'bonus': False, 'bike_stands': 40, 'available_bike_stands': 32, 'available_bikes': 8, 'status': 'OPEN', 'last_update': 1677175099000}
# 2023-02-23 17:59:31,421 INFO sqlalchemy.engine.Engine insert into station values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2023-02-23 17:59:31,423 INFO sqlalchemy.engine.Engine [raw sql] ('St James Hospital (Luas)', 0, 40, 0, 'dublin', 'ST JAMES HOSPITAL (LUAS)', 80, 53.341359, -6.292951, 'OPEN')
# 2023-02-23 17:59:31,689 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 41, 'contract_name': 'dublin', 'name': 'HARCOURT TERRACE', 'address': 'Harcourt Terrace', 'position': {'lat': 53.332763, 'lng': -6.257942}, 'banking': False, 'bonus': False, 'bike_stands': 20, 'available_bike_stands': 17, 'available_bikes': 3, 'status': 'OPEN', 'last_update': 1677174997000}
# 2023-02-23 17:59:31,883 INFO sqlalchemy.engine.Engine insert into station values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2023-02-23 17:59:31,885 INFO sqlalchemy.engine.Engine [raw sql] ('Harcourt Terrace', 0, 20, 0, 'dublin', 'HARCOURT TERRACE', 41, 53.332763, -6.257942, 'OPEN')
# 2023-02-23 17:59:31,979 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 3, 'contract_name': 'dublin', 'name': 'BOLTON STREET', 'address': 'Bolton Street', 'position': {'lat': 53.351182, 'lng': -6.269859}, 'banking': False, 'bonus': False, 'bike_stands': 20, 'available_bike_stands': 12, 'available_bikes': 8, 'status': 'OPEN', 'last_update': 1677174930000}
# 2023-02-23 17:59:32,306 INFO sqlalchemy.engine.Engine insert into station values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2023-02-23 17:59:32,307 INFO sqlalchemy.engine.Engine [raw sql] ('Bolton Street', 0, 20, 0, 'dublin', 'BOLTON STREET', 3, 53.351182, -6.269859, 'OPEN')
# 2023-02-23 17:59:32,401 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 40, 'contract_name': 'dublin', 'name': 'JERVIS STREET', 'address': 'Jervis Street', 'position': {'lat': 53.3483, 'lng': -6.266651}, 'banking': False, 'bonus': False, 'bike_stands': 21, 'available_bike_stands': 21, 'available_bikes': 0, 'status': 'OPEN', 'last_update': 1677174623000}
# 2023-02-23 17:59:32,739 INFO sqlalchemy.engine.Engine insert into station values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2023-02-23 17:59:32,741 INFO sqlalchemy.engine.Engine [raw sql] ('Jervis Street', 0, 21, 0, 'dublin', 'JERVIS STREET', 40, 53.3483, -6.266651, 'OPEN')
# 2023-02-23 17:59:32,860 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 29, 'contract_name': 'dublin', 'name': 'ORMOND QUAY UPPER', 'address': 'Ormond Quay Upper', 'position': {'lat': 53.346057, 'lng': -6.268001}, 'banking': False, 'bonus': False, 'bike_stands': 29, 'available_bike_stands': 19, 'available_bikes': 9, 'status': 'OPEN', 'last_update': 1677174826000}
# 2023-02-23 17:59:33,056 INFO sqlalchemy.engine.Engine insert into station values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2023-02-23 17:59:33,059 INFO sqlalchemy.engine.Engine [raw sql] ('Ormond Quay Upper', 0, 29, 0, 'dublin', 'ORMOND QUAY UPPER', 29, 53.346057, -6.268001, 'OPEN')
# 2023-02-23 17:59:33,262 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 103, 'contract_name': 'dublin', 'name': 'GRANGEGORMAN LOWER (SOUTH)', 'address': 'Grangegorman Lower (South)', 'position': {'lat': 53.354663, 'lng': -6.278681}, 'banking': False, 'bonus': False, 'bike_stands': 40, 'available_bike_stands': 40, 'available_bikes': 0, 'status': 'OPEN', 'last_update': 1677175091000}
# 2023-02-23 17:59:33,457 INFO sqlalchemy.engine.Engine insert into station values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2023-02-23 17:59:33,459 INFO sqlalchemy.engine.Engine [raw sql] ('Grangegorman Lower (South)', 0, 40, 0, 'dublin', 'GRANGEGORMAN LOWER (SOUTH)', 103, 53.354663, -6.278681, 'OPEN')
# 2023-02-23 17:59:33,770 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 28, 'contract_name': 'dublin', 'name': 'MOUNTJOY SQUARE WEST', 'address': 'Mountjoy Square West', 'position': {'lat': 53.356299, 'lng': -6.258586}, 'banking': False, 'bonus': False, 'bike_stands': 30, 'available_bike_stands': 17, 'available_bikes': 13, 'status': 'OPEN', 'last_update': 1677175105000}
# 2023-02-23 17:59:33,976 INFO sqlalchemy.engine.Engine insert into station values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2023-02-23 17:59:33,977 INFO sqlalchemy.engine.Engine [raw sql] ('Mountjoy Square West', 0, 30, 0, 'dublin', 'MOUNTJOY SQUARE WEST', 28, 53.356299, -6.258586, 'OPEN')
# 2023-02-23 17:59:34,071 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 39, 'contract_name': 'dublin', 'name': 'WILTON TERRACE', 'address': 'Wilton Terrace', 'position': {'lat': 53.332383, 'lng': -6.252717}, 'banking': False, 'bonus': False, 'bike_stands': 20, 'available_bike_stands': 17, 'available_bikes': 3, 'status': 'OPEN', 'last_update': 1677175096000}
# 2023-02-23 17:59:34,266 INFO sqlalchemy.engine.Engine insert into station values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2023-02-23 17:59:34,269 INFO sqlalchemy.engine.Engine [raw sql] ('Wilton Terrace', 0, 20, 0, 'dublin', 'WILTON TERRACE', 39, 53.332383, -6.252717, 'OPEN')
# 2023-02-23 17:59:34,364 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 83, 'contract_name': 'dublin', 'name': 'EMMET ROAD', 'address': 'Emmet Road', 'position': {'lat': 53.340714, 'lng': -6.308191}, 'banking': False, 'bonus': False, 'bike_stands': 40, 'available_bike_stands': 32, 'available_bikes': 8, 'status': 'OPEN', 'last_update': 1677174957000}
# 2023-02-23 17:59:34,555 INFO sqlalchemy.engine.Engine insert into station values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2023-02-23 17:59:34,557 INFO sqlalchemy.engine.Engine [raw sql] ('Emmet Road', 0, 40, 0, 'dublin', 'EMMET ROAD', 83, 53.340714, -6.308191, 'OPEN')
# 2023-02-23 17:59:34,652 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 92, 'contract_name': 'dublin', 'name': 'HEUSTON BRIDGE (NORTH)', 'address': 'Heuston Bridge (North)', 'position': {'lat': 53.347802, 'lng': -6.292432}, 'banking': False, 'bonus': False, 'bike_stands': 40, 'available_bike_stands': 0, 'available_bikes': 40, 'status': 'OPEN', 'last_update': 1677174982000}
# 2023-02-23 17:59:34,848 INFO sqlalchemy.engine.Engine insert into station values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2023-02-23 17:59:34,850 INFO sqlalchemy.engine.Engine [raw sql] ('Heuston Bridge (North)', 0, 40, 0, 'dublin', 'HEUSTON BRIDGE (NORTH)', 92, 53.347802, -6.292432, 'OPEN')
# 2023-02-23 17:59:34,945 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 21, 'contract_name': 'dublin', 'name': 'LEINSTER STREET SOUTH', 'address': 'Leinster Street South', 'position': {'lat': 53.34218, 'lng': -6.254485}, 'banking': False, 'bonus': False, 'bike_stands': 30, 'available_bike_stands': 17, 'available_bikes': 13, 'status': 'OPEN', 'last_update': 1677175097000}
# 2023-02-23 17:59:35,138 INFO sqlalchemy.engine.Engine insert into station values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2023-02-23 17:59:35,140 INFO sqlalchemy.engine.Engine [raw sql] ('Leinster Street South', 0, 30, 0, 'dublin', 'LEINSTER STREET SOUTH', 21, 53.34218, -6.254485, 'OPEN')
# 2023-02-23 17:59:35,235 INFO sqlalchemy.engine.Engine COMMIT
# {'number': 88, 'contract_name': 'dublin', 'name': 'BLACKHALL PLACE', 'address': 'Blackhall Place', 'position': {'lat': 53.3488, 'lng': -6.281637}, 'banking': False, 'bonus': False, 'bike_stands': 30, 'available_bike_stands': 20, 'available_bikes': 10, 'status': 'OPEN', 'last_update': 1677174932000}
# 2023-02-23 17:59:35,428 INFO sqlalchemy.engine.Engine insert into station values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2023-02-23 17:59:35,430 INFO sqlalchemy.engine.Engine [raw sql] ('Blackhall Place', 0, 30, 0, 'dublin', 'BLACKHALL PLACE', 88, 53.3488, -6.281637, 'OPEN')
# 2023-02-23 17:59:35,524 INFO sqlalchemy.engine.Engine COMMIT
